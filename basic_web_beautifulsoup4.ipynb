# %% [markdown]
# Today we'll build upon our earlier lesson in the basic_web_plus_api_call_interactions lesson. Remember during that lesson we learned about the webbrowser module, learned how to properly format a URL to use webbrowser, and followed that with using an API call to request some basic information from a web page.  However not all content you may want to download from a script will have an API that you can directly interact with.  Sometimes you will have to actually scrape that content for what you are looking to find.
#
# Reference:
# https://automatetheboringstuff.com/chapter11/

# %%
'''
Fairly simliar to the last lesson with requests, we need to install the module
'''
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\estyw\anaconda3\lib\site-packages (4.6.3)

# %%
# prep for below
import os
import sys

# %% [markdown]
# Ok, now we'll have to import this module.  Note that up until now everything we've used we haven able to import it by the name we installed it with.  Unfortunantely, beautifulsoup4 is not this way.  Take a moment to read the below:
#
# https://docs.python.org/3/tutorial/modules.html#the-module-search-path
#
# Let's take a step and look through this.  Everything you installed with pip gets installed under the site packages directory in your PYTHON_PATH.  So you *should* be able to do the following and see beautifulsoup (somewhere in the results) assuming you are on python3.6.

# %%
os.listdir('C:/Users/estyw/Anaconda3/Lib/site-packages')
# Out:
# ['adodbapi',
#  'alabaster',
#  'alabaster-0.7.12.dist-info',
#  'anaconda_client-1.7.2-py3.7.egg-info',
#  'anaconda_navigator',
#  'anaconda_navigator-1.9.6-py3.7.egg-info',
#  'anaconda_project',
#  'anaconda_project-0.8.2-py3.7.egg-info',
#  'asn1crypto',
#  'asn1crypto-0.24.0-py3.7.egg-info',
#  'astroid',
#  'astroid-2.1.0.dist-info',
#  'astropy',
#  'astropy-3.1-py3.7.egg-info',
#  'atomicwrites',
#  'atomicwrites-1.2.1-py3.7.egg-info',
#  'attr',
#  'attrs-18.2.0.dist-info',
#  'babel',
#  'Babel-2.6.0-py3.7.egg-info',
#  'backcall',
#  'backcall-0.1.0.dist-info',
#  'backports',
#  'backports.os-0.1.1-py3.7.egg-info',
#  'backports.shutil_get_terminal_size-1.0.0.dist-info',
#  'beautifulsoup4-4.6.3.dist-info',
#  'binstar_client',
#  'bitarray',
#  'bitarray-0.8.3-py3.7.egg-info',
#  'bkcharts',
#  'bkcharts-0.2-py3.7.egg-info',
#  'blaze',
#  'blaze-0.11.3-py3.7.egg-info',
#  'bleach',
#  'bleach-3.0.2-py3.7.egg-info',
#  'bokeh',
#  'bokeh-1.0.2.dist-info',
#  'boto',
#  'boto-2.49.0-py3.7.egg-info',
#  'bottleneck',
#  'Bottleneck-1.2.1-py3.7.egg-info',
#  'bs4',
#  'certifi',
#  'certifi-2018.11.29-py3.7.egg-info',
#  'cffi',
#  'cffi-1.11.5.dist-info',
#  'chardet',
#  'chardet-3.0.4-py3.7.egg-info',
#  'click',
#  'Click-7.0-py3.7.egg-info',
#  'cloudpickle',
#  'cloudpickle-0.6.1.dist-info',
#  'clyent',
#  'clyent-1.2.2-py3.7.egg-info',
#  'colorama',
#  'colorama-0.4.1-py3.7.egg-info',
#  'comtypes',
#  'comtypes-1.1.7-py3.7.egg-info',
#  'conda',
#  'conda-4.5.12-py3.7.egg-info',
#  'conda_build',
#  'conda_build-3.17.6-py3.7.egg-info',
#  'conda_env',
#  'conda_verify',
#  'conda_verify-3.1.1-py3.7.egg-info',
#  'contextlib2-0.5.5-py3.7.egg-info',
#  'contextlib2.py',
#  'Crypto',
#  'cryptography',
#  'cryptography-2.4.2.dist-info',
#  'curl',
#  'cycler-0.10.0-py3.7.egg-info',
#  'cycler.py',
#  'Cython',
#  'Cython-0.29.2.dist-info',
#  'cython.py',
#  'cytoolz',
#  'cytoolz-0.9.0.1-py3.7.egg-info',
#  'dask',
#  'dask-1.0.0.dist-info',
#  'datashape',
#  'datashape-0.5.4-py3.7.egg-info',
#  'dateutil',
#  'decorator-4.3.0.dist-info',
#  'decorator.py',
#  'defusedxml',
#  'defusedxml-0.5.0-py3.7.egg-info',
#  'distributed',
#  'distributed-1.25.1-py3.7.egg-info',
#  'docutils',
#  'docutils-0.14-py3.7.egg-info',
#  'easy_install.py',
#  'entrypoints-0.2.3-py3.7.egg-info',
#  'entrypoints.py',
#  'et_xmlfile',
#  'et_xmlfile-1.0.1-py3.7.egg-info',
#  'fastcache',
#  'fastcache-1.0.2-py3.7.egg-info',
#  'filelock-3.0.10.dist-info',
#  'filelock.py',
#  'flask',
#  'Flask-1.0.2.dist-info',
#  'flask_cors',
#  'Flask_Cors-3.0.7.dist-info',
#  'future',
#  'future-0.17.1-py3.7.egg-info',
#  'gevent',
#  'gevent-1.3.7-py3.7.egg-info',
#  'glob2',
#  'glob2-0.6-py3.7.egg-info',
#  'greenlet-0.4.15.dist-info',
#  'greenlet.cp37-win_amd64.pyd',
#  'h5py',
#  'h5py-2.8.0-py3.7.egg-info',
#  'heapdict-1.0.0-py3.7.egg-info',
#  'heapdict.py',
#  'html5lib',
#  'html5lib-1.0.1.dist-info',
#  'idna',
#  'idna-2.8-py3.7.egg-info',
#  'imageio',
#  'imageio-2.4.1-py3.7.egg-info',
#  'imagesize-1.1.0.dist-info',
#  'imagesize.py',
#  'importlib_metadata',
#  'importlib_metadata-0.6.dist-info',
#  'ipykernel',
#  'ipykernel-5.1.0.dist-info',
#  'ipykernel_launcher.py',
#  'IPython',
#  'ipython-7.2.0.dist-info',
#  'ipython_genutils',
#  'ipython_genutils-0.2.0-py3.7.egg-info',
#  'ipywidgets',
#  'ipywidgets-7.4.2.dist-info',
#  'isapi',
#  'isort',
#  'isort-4.3.4-py3.7.egg-info',
#  'isympy.py',
#  'itsdangerous',
#  'itsdangerous-1.1.0.dist-info',
#  'jdcal-1.4-py3.7.egg-info',
#  'jdcal.py',
#  'jedi',
#  'jedi-0.13.2-py3.7.egg-info',
#  'jinja2',
#  'Jinja2-2.10-py3.7.egg-info',
#  'jsonschema',
#  'jsonschema-2.6.0-py3.7.egg-info',
#  'jupyter-1.0.0.dist-info',
#  'jupyter.py',
#  'jupyterlab',
#  'jupyterlab-0.35.3-py3.7.egg-info',
#  'jupyterlab_server',
#  'jupyterlab_server-0.2.0.dist-info',
#  'jupyter_client',
#  'jupyter_client-5.2.4.dist-info',
#  'jupyter_console',
#  'jupyter_console-6.0.0-py3.7.egg-info',
#  'jupyter_core',
#  'jupyter_core-4.4.0.dist-info',
#  'keyring',
#  'keyring-17.0.0-py3.7.egg-info',
#  'kiwisolver-1.0.1-py3.7.egg-info',
#  'kiwisolver.cp37-win_amd64.pyd',
#  'lazy_object_proxy',
#  'lazy_object_proxy-1.3.1-py3.7.egg-info',
#  'libarchive',
#  'libarchive_c-2.8-py3.7.egg-info',
#  'libfuturize',
#  'libpasteurize',
#  'llvmlite',
#  'llvmlite-0.26.0-py3.7.egg-info',
#  'locket',
#  'locket-0.2.0-py3.7.egg-info',
#  'lxml',
#  'lxml-4.2.5.dist-info',
#  'markupsafe',
#  'MarkupSafe-1.1.0-py3.7.egg-info',
#  'matplotlib',
#  'matplotlib-3.0.2-py3.7-nspkg.pth',
#  'matplotlib-3.0.2-py3.7.egg-info',
#  'mccabe-0.6.1-py3.7.egg-info',
#  'mccabe.py',
#  'menuinst',
#  'menuinst-1.4.14-py3.7.egg-info',
#  'mistune-0.8.4.dist-info',
#  'mistune.py',
#  'mkl',
#  'mkl_fft',
#  'mkl_fft-1.0.6-py3.7.egg-info',
#  'mkl_random',
#  'mkl_random-1.0.2-py3.7.egg-info',
#  'more_itertools',
#  'more_itertools-4.3.0-py3.7.egg-info',
#  'mpl_toolkits',
#  'mpmath',
#  'mpmath-1.1.0-py3.7.egg-info',
#  'msgpack',
#  'msgpack-0.5.6.dist-info',
#  'multipledispatch',
#  'multipledispatch-0.6.0-py3.7.egg-info',
#  'navigator_updater',
#  'navigator_updater-0.2.1-py3.7.egg-info',
#  'nbconvert',
#  'nbconvert-5.4.0-py3.7.egg-info',
#  'nbformat',
#  'nbformat-4.4.0.dist-info',
#  'networkx',
#  'networkx-2.2-py3.7.egg-info',
#  'nltk',
#  'nltk-3.4-py3.7.egg-info',
#  'nose',
#  'nose-1.3.7-py3.7.egg-info',
#  'notebook',
#  'notebook-5.7.4.dist-info',
#  'numba',
#  'numba-0.41.0-py3.7.egg-info',
#  'numexpr',
#  'numexpr-2.6.8-py3.7.egg-info',
#  'numpy',
#  'numpy-1.15.4-py3.7.egg-info',
#  'numpydoc',
#  'numpydoc-0.8.0-py3.7.egg-info',
#  'odo',
#  'odo-0.5.1-py3.7.egg-info',
#  'olefile',
#  'olefile-0.46-py3.7.egg-info',
#  'openpyxl',
#  'openpyxl-2.5.12.dist-info',
#  'OpenSSL',
#  'packaging',
#  'packaging-18.0.dist-info',
#  'pandas',
#  'pandas-0.23.4-py3.7.egg-info',
#  'pandocfilters-1.4.2.dist-info',
#  'pandocfilters.py',
#  'parso',
#  'parso-0.3.1.dist-info',
#  'partd',
#  'partd-0.3.9.dist-info',
#  'past',
#  'path.py',
#  'path.py-11.5.0.dist-info',
#  'pathlib2',
#  'pathlib2-2.3.3-py3.7.egg-info',
#  'patsy',
#  'patsy-0.5.1-py3.7.egg-info',
#  'pep8-1.7.1-py3.7.egg-info',
#  'pep8.py',
#  'pickleshare-0.7.5-py3.7.egg-info',
#  'pickleshare.py',
#  'PIL',
#  'Pillow-5.3.0-py3.7.egg-info',
#  'pip',
#  'pip-18.1-py3.7.egg-info',
#  'pkginfo',
#  'pkginfo-1.4.2-py3.7.egg-info',
#  'pkg_resources',
#  'pluggy',
#  'pluggy-0.8.0.dist-info',
#  'ply',
#  'ply-3.11-py3.7.egg-info',
#  'prometheus_client',
#  'prometheus_client-0.5.0-py3.7.egg-info',
#  'prompt_toolkit',
#  'prompt_toolkit-2.0.7.dist-info',
#  'psutil',
#  'psutil-5.4.8.dist-info',
#  'py',
#  'py-1.7.0.dist-info',
#  'pycodestyle-2.4.0-py3.7.egg-info',
#  'pycodestyle.py',
#  'pycosat-0.6.3-py3.7.egg-info',
#  'pycosat.cp37-win_amd64.pyd',
#  'pycparser',
#  'pycparser-2.19-py3.7.egg-info',
#  'pycrypto-2.6.1-py3.7.egg-info',
#  'pycurl-7.43.0.2-py3.7.egg-info',
#  'pycurl.cp37-win_amd64.pyd',
#  'pyflakes',
#  'pyflakes-2.0.0.dist-info',
#  'pygments',
#  'Pygments-2.3.1-py3.7.egg-info',
#  'pylab.py',
#  'pylint',
#  'pylint-2.2.2-py3.7.egg-info',
#  'pyodbc-4.0.25-py3.7.egg-info',
#  'pyodbc.cp37-win_amd64.pyd',
#  'pyOpenSSL-18.0.0.dist-info',
#  'pyparsing-2.3.0.dist-info',
#  'pyparsing.py',
#  'PyQt5',
#  'PySocks-1.6.8-py3.7.egg-info',
#  'pytest-4.0.2-py3.7.egg-info',
#  'pytest.py',
#  'pytest_arraydiff',
#  'pytest_arraydiff-0.3.dist-info',
#  'pytest_astropy-0.5.0.dist-info',
#  'pytest_doctestplus',
#  'pytest_doctestplus-0.2.0.dist-info',
#  'pytest_openfiles',
#  'pytest_openfiles-0.3.1.dist-info',
#  'pytest_remotedata',
#  'pytest_remotedata-0.3.1.dist-info',
#  'pythoncom.py',
#  'pythonwin',
#  'python_dateutil-2.7.5.dist-info',
#  'pytz',
#  'pytz-2018.7.dist-info',
#  'PyWavelets-1.0.1.dist-info',
#  'pywin32-223-py3.7.egg-info',
#  'pywin32.pth',
#  'pywin32.version.txt',
#  'pywin32_system32',
#  'pywinpty-0.5.5-py3.7.egg-info',
#  'pywt',
#  'pyximport',
#  'PyYAML-3.13-py3.7.egg-info',
#  'pyzmq-17.1.2-py3.7.egg-info',
#  'qtawesome',
#  'QtAwesome-0.5.3-py3.7.egg-info',
#  'qtconsole',
#  'qtconsole-4.4.3-py3.7.egg-info',
#  'qtpy',
#  'QtPy-1.5.2.dist-info',
#  'README.txt',
#  'requests',
#  'requests-2.21.0.dist-info',
#  'rope',
#  'rope-0.11.0-py3.7.egg-info',
#  'ruamel_yaml',
#  'ruamel_yaml-0.15.46-py3.7.egg-info',
#  'run.py',
#  'scikit_image-0.14.1-py3.7.egg-info',
#  'scikit_learn-0.20.1-py3.7.egg-info',
#  'scipy',
#  'scipy-1.1.0-py3.7.egg-info',
#  'scripts',
#  'seaborn',
#  'seaborn-0.9.0.dist-info',
#  'send2trash',
#  'Send2Trash-1.5.0-py3.7.egg-info',
#  'setuptools',
#  'setuptools-40.6.3-py3.7.egg-info',
#  'simplegeneric-0.8.1-py3.7.egg-info',
#  'simplegeneric.py',
#  'singledispatch-3.4.0.3-py3.7.egg-info',
#  'singledispatch.py',
#  'singledispatch_helpers.py',
#  'sip.pyd',
#  'sip.pyi',
#  'sipconfig.py',
#  'sipdistutils.py',
#  'six-1.12.0-py3.7.egg-info',
#  'six.py',
#  'skimage',
#  'sklearn',
#  'sklearn-0.0.dist-info',
#  'snowballstemmer',
#  'snowballstemmer-1.2.1-py3.7.egg-info',
#  'socks.py',
#  'sockshandler.py',
#  'sortedcollections',
#  'sortedcollections-1.0.1-py3.7.egg-info',
#  'sortedcontainers',
#  'sortedcontainers-2.1.0-py3.7.egg-info',
#  'sphinx',
#  'Sphinx-1.8.2-py3.7.egg-info',
#  'sphinxcontrib',
#  'sphinxcontrib_websupport-1.1.0-py3.7-nspkg.pth',
#  'sphinxcontrib_websupport-1.1.0-py3.7.egg-info',
#  'spyder',
#  'spyder-3.3.2.dist-info',
#  'spyder_breakpoints',
#  'spyder_io_dcm',
#  'spyder_io_hdf5',
#  'spyder_kernels',
#  'spyder_kernels-0.3.0.dist-info',
#  'spyder_profiler',
#  'spyder_pylint',
#  'sqlalchemy',
#  'SQLAlchemy-1.2.15.dist-info',
#  'statsmodels',
#  'statsmodels-0.9.0-py3.7.egg-info',
#  'sympy',
#  'sympy-1.3-py3.7.egg-info',
#  'tables',
#  'tables-3.4.4-py3.7.egg-info',
#  'tblib',
#  'tblib-1.3.2-py3.7.egg-info',
#  'terminado',
#  'terminado-0.8.1-py3.7.egg-info',
#  'testpath',
#  'testpath-0.4.2.dist-info',
#  'test_path.py',
#  'test_pycosat.py',
#  'tlz',
#  'toolz',
#  'toolz-0.9.0-py3.7.egg-info',
#  'tornado',
#  'tornado-5.1.1-py3.7.egg-info',
#  'tqdm',
#  'tqdm-4.28.1.dist-info',
#  'traitlets',
#  'traitlets-4.3.2.dist-info',
#  'unicodecsv',
#  'unicodecsv-0.14.1-py3.7.egg-info',
#  'urllib3',
#  'urllib3-1.24.1-py3.7.egg-info',
#  'wcwidth',
#  'wcwidth-0.1.7-py3.7.egg-info',
#  'webencodings',
#  'webencodings-0.5.1-py3.7.egg-info',
#  'werkzeug',
#  'Werkzeug-0.14.1-py3.7.egg-info',
#  'wheel',
#  'wheel-0.32.3-py3.7.egg-info',
#  'widgetsnbextension',
#  'widgetsnbextension-3.4.2-py3.7.egg-info',
#  'win32',
#  'win32com',
#  'win32comext',
#  'wincertstore-0.2-py3.7.egg-info',
#  'wincertstore.py',
#  'winpty',
#  'win_inet_pton-1.0.1-py3.7.egg-info',
#  'win_inet_pton.py',
#  'win_unicode_console',
#  'win_unicode_console-0.5-py3.7.egg-info',
#  'wrapt',
#  'wrapt-1.10.11-py3.7.egg-info',
#  'xlrd',
#  'xlrd-1.2.0.dist-info',
#  'xlsxwriter',
#  'XlsxWriter-1.1.2.dist-info',
#  'xlwings',
#  'xlwings-0.15.1-py3.7.egg-info',
#  'xlwt',
#  'xlwt-1.3.0-py3.7.egg-info',
#  'xonsh',
#  'yaml',
#  'zict',
#  'zict-0.1.3-py3.7.egg-info',
#  'zmq',
#  '_cffi_backend.cp37-win_amd64.pyd',
#  '_pytest',
#  '_yaml.cp37-win_amd64.pyd',
#  '__pycache__']

# %% [markdown]
# That's a lot to look through, let's see if we can at this without hard coding our python version in and without opening a file browser to look for this manually.  Let's inspect the contents of PYTHONPATH.  In your command prompt or bash shell, that is the variable.  In your Python code it's known as sys.path so you can just get the list now.

# %%
sys.path
# Out:
# ['C:\\Users\\estyw\\Desktop\\Python Instruction\\python-instruction-master',
#  'C:\\Users\\estyw\\Anaconda3\\python37.zip',
#  'C:\\Users\\estyw\\Anaconda3\\DLLs',
#  'C:\\Users\\estyw\\Anaconda3\\lib',
#  'C:\\Users\\estyw\\Anaconda3',
#  '',
#  'C:\\Users\\estyw\\AppData\\Roaming\\Python\\Python37\\site-packages',
#  'C:\\Users\\estyw\\Anaconda3\\lib\\site-packages',
#  'C:\\Users\\estyw\\Anaconda3\\lib\\site-packages\\win32',
#  'C:\\Users\\estyw\\Anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\estyw\\Anaconda3\\lib\\site-packages\\Pythonwin',
#  'C:\\Users\\estyw\\Anaconda3\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\estyw\\.ipython']

# %% [markdown]
# Phew, that's still a bunch of directories to look through. Let's see if we can get through them in just a few lines of code and find beautifulsoup4.  Since we didn't see a module named "beautifulsoup4" above let's look through for modules that start with the letter "b".

# %%
for dir in sys.path:
    if os.path.exists(dir):
        print([x for x in os.listdir(dir) if x.startswith('b')])
# Out:
# ['basic_database_tech.ipynb', 'basic_web_beautifulsoup4.ipynb', 'basic_web_plus_api_call_interactions.ipynb']
# []
# ['base64.py', 'bdb.py', 'binhex.py', 'bisect.py', 'bz2.py']
# []
# []
# ['babel', 'backcall', 'backcall-0.1.0.dist-info', 'backports', 'backports.os-0.1.1-py3.7.egg-info', 'backports.shutil_get_terminal_size-1.0.0.dist-info', 'beautifulsoup4-4.6.3.dist-info', 'binstar_client', 'bitarray', 'bitarray-0.8.3-py3.7.egg-info', 'bkcharts', 'bkcharts-0.2-py3.7.egg-info', 'blaze', 'blaze-0.11.3-py3.7.egg-info', 'bleach', 'bleach-3.0.2-py3.7.egg-info', 'bokeh', 'bokeh-1.0.2.dist-info', 'boto', 'boto-2.49.0-py3.7.egg-info', 'bottleneck', 'bs4']
# []
# []
# []
# []
# []

# %% [markdown]
# That was a bit of a pain, but above I see the "bs4" directory...
#
# Let's just look at the internet for the documentation on beautifulsoup4.

# %%
import webbrowser
webbrowser.open("https://pypi.org/search/?q=beautifulsoup4")
# Out:
# True

# %% [markdown]
# Moral of the story, modules don't always get installed with the same name that you installed for the package name. Even if you ask pip what it knows about beautifulsoup4 you won't see that it's actually called 'bs4'. Sadly this is a Python packaging nuance and you'll find it's easiest just to reference PyPi.org for information regarding the package name or search for information about it. It's usually a bit quicker than trying to guess or look through directories on what the package name actually is called.

# %%
# !pip show -v beautifulsoup4
# Out:
# Name: beautifulsoup4
# Version: 4.6.3
# Summary: Screen-scraping library
# Home-page: http://www.crummy.com/software/BeautifulSoup/bs4/
# Author: Leonard Richardson
# Author-email: leonardr@segfault.org
# License: MIT
# Location: c:\users\estyw\anaconda3\lib\site-packages
# Requires:
# Required-by: conda-build
# Metadata-Version: 2.1
# Installer: pip
# Classifiers:
#   Development Status :: 5 - Production/Stable
#   Intended Audience :: Developers
#   License :: OSI Approved :: MIT License
#   Programming Language :: Python
#   Programming Language :: Python :: 2.7
#   Programming Language :: Python :: 3
#   Topic :: Text Processing :: Markup :: HTML
#   Topic :: Text Processing :: Markup :: XML
#   Topic :: Text Processing :: Markup :: SGML
#   Topic :: Software Development :: Libraries :: Python Modules
# Entry-points:

# %% [markdown]
# Let's import this along with requests from yesterday and move on...

# %%
# !pip install requests
import requests, bs4
# Out:
# Requirement already satisfied: requests in c:\users\estyw\anaconda3\lib\site-packages (2.21.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\estyw\anaconda3\lib\site-packages (from requests) (1.24.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\estyw\anaconda3\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\estyw\anaconda3\lib\site-packages (from requests) (2018.11.29)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\estyw\anaconda3\lib\site-packages (from requests) (2.8)

# %% [markdown]
# Let's start by learning a bit about HTML. HTML is the Hypertext Markup Language. Text in HTML is surrounded by tags which tell your browser how to render the content. Take a look here to learn a bit more about HTML.
#
# Reference: https://www.dataquest.io/blog/web-scraping-tutorial-python/

# %%
# NOT IMPLEMENTED YET - Add html/head/title/paragraph tags
test = '''
<html>
    <head>
    <title>
    This is the title!
    </title>
    </head>
    <body>
        <p>
        This is in the first paragraph element
        </p>
        <p>
        This is in the second paragraph element
        </p>
        <p>
        This is in the third paragraph tag
        </p>
        <p>
        <b> This is the fourth paragraph and it's important so put bold tags on it too </b>
        </p>
    </body>
</html>
'''

# %%
# Make some soup!
soup = bs4.BeautifulSoup(test)

# %%
# NOT IMPLEMENTED YET - find all paragraph tags
soup.find_all('p')
# Out:
# [<p>
#          This is in the first paragraph element
#          </p>, <p>
#          This is in the second paragraph element
#          </p>, <p>
#          This is in the third paragraph tag
#          </p>, <p>
#  <b> This is the fourth paragraph and it's important so put bold tags on it too </b>
#  </p>]

# %% [markdown]
# At this point you got the basic idea on how to request all the paragraph elements from a page you wrote. So let's take this to the next step and parse out content of a page you didn't write. However you can expect a consistent output to look for results. We'll be doing a bit of scraping of stock quotes.  Take a look here for more.
#
# Reference:  http://altitudelabs.com/blog/web-scraping-with-python-and-beautiful-soup/
#
# However, I want you do a little research on Bloomberg and get your program to print out the "Dow Jones Industrial Average" quote rather than what is shown here.

# %%
# NOT IMPLEMENTED YET - Define Dow Jones Industrial Average URL
dowurl = "https://www.bloomberg.com/quote/INDU:IND/"
# NOT IMPLEMENTED YET - Get the HTML of the page using requests
dowhtml = requests.get(dowurl)
# NOT IMPLEMENTED YET - Parse the text and get the name and the price
soup2 = bs4.BeautifulSoup(dowhtml.content, 'html.parser')
# NOT IMPLEMENTED YET - Display results
soup2.find_all('title')
# Out:
# [<title>Bloomberg - Are you a robot?</title>]

# %% [markdown]
# The reference for this exercise handed you the fields to search for. Take a moment to do the following and examine the developer tools built into the browser. You can get to this by clicking the settings -> more tools -> developer tools (on Chrome). Search for the companyName and priceText fields.
