# %% [markdown]
# Today we'll learn how to do some basic web interactions. The end
# state will be you have an introductory knowledge towards requesting
# data in your Python scripts from external websites.
#
# This will be based on Automate the Boring Stuff chapter 11 with some
# supplementary material for saving that data from chapter 14.
#
# Reference:
# https://automatetheboringstuff.com/chapter11/
# https://automatetheboringstuff.com/chapter14/

# %%
'''
Start with importing and doing a basic check of the webbrowser
module. Note that since you are already in jupyter notebook this
will just open a new tab.
'''
import webbrowser
webbrowser.open('https://www.google.com')
# Out:
# True

# %%
'''
You can take this to the next step by opening a more specific URL path
'''
address = "Washington DC"
webbrowser.open('https://www.google.com/maps/place/' + address)
# Out:
# True

# %%
'''
Often you can get what you are looking for by formatting a search with
the correct terms. Adjust this to do a plain search on google.com below.
This is essentially entry level URL dorking and you can use this in the
future to format more advanced search strings.

Before you change anything, take a note of the different style of comment
blocks.  The triple quote style can be used to enclose large chunks of
text while the hashtag you see below can only comment a single line.
'''
def lmgtfy(search):
    webbrowser.open('https://www.google.com/search?q=' + search)
    pass
    
lmgtfy("python learning")

# %% [markdown]
# Our next learning objective will be basic usage of the requests module.
# Opening a web page in a browser usually isn't of value for your scripts.
# Requests will let you programatically download a page and you can take
# further actions on it in code.
#
# Let's start by installing it.

# %%
# !pip install requests

# %% [markdown]
# Import all modules you will need for the next section. You can read
# a bit more for what you will need at the links below.
#
# https://docs.python.org/3/library/csv.html
#
# http://docs.python-requests.org/en/master/user/quickstart/#json-response-content

# %%
import csv
import os
import requests

# %% [markdown]
# Fetch the information you will need. Note you only need to do this
# once as further work you will do will already be stored in the 'r'
# variable.

# %%
# GET /eventsm
r = requests.get('https://api.github.com/events')

# %% [markdown]
# One of the key aspects of data science often comes down to understanding the data you are looking at. Let's take a moment to inspect three different syntaxes.

# %%
'''
Inspect full .json() method

Look very close at the results, note the first character is
a [ meaning the result is a list. Note the second character
is a { meaning each entry in the list is a dictionary.
'''
r.json()
# Out:
# [{'id': '9505016235',
#   'type': 'PushEvent',
#   'actor': {'id': 15008142,
#    'login': 'wenxuans',
#    'display_login': 'wenxuans',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wenxuans',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15008142?'},
#   'repo': {'id': 178074109,
#    'name': 'miaschoening1/ReconnectApp',
#    'url': 'https://api.github.com/repos/miaschoening1/ReconnectApp'},
#   'payload': {'push_id': 3542382603,
#    'size': 12,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '973de68ecb3315edd0cbd04b876228df7ddd228f',
#    'before': 'db41bd712d69aebe082ecd76fe287ed43115d9ba',
#    'commits': [{'sha': 'd7392cea71239bb960cecd17e9607ad938653039',
#      'author': {'email': 'wshi0810@gmail.com', 'name': 'Wendy'},
#      'message': 'Set up Summary activity',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/miaschoening1/ReconnectApp/commits/d7392cea71239bb960cecd17e9607ad938653039'},
#     {'sha': 'f3528b6a0dc72343d7863e81ecc8361a961e18ce',
#      'author': {'email': 'wshi0810@gmail.com', 'name': 'Wendy'},
#      'message': "Merge branch 'mia' of https://github.com/miaschoening1/ReconnectApp into wendy",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/miaschoening1/ReconnectApp/commits/f3528b6a0dc72343d7863e81ecc8361a961e18ce'},
#     {'sha': 'ee90968003b9f9a2b7f32990fe78588766e9bfd4',
#      'author': {'email': 'wshi0810@gmail.com', 'name': 'Wendy'},
#      'message': 'Set up Summary layout',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/miaschoening1/ReconnectApp/commits/ee90968003b9f9a2b7f32990fe78588766e9bfd4'},
#     {'sha': 'de801f0403a4dd8fff644bdc8de30843e57369fc',
#      'author': {'email': 'wshi0810@gmail.com', 'name': 'Wendy'},
#      'message': 'Added dropdown style',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/miaschoening1/ReconnectApp/commits/de801f0403a4dd8fff644bdc8de30843e57369fc'},
#     {'sha': '91761e045486a26569492bb16f014debd69abef9',
#      'author': {'email': 'wshi0810@gmail.com', 'name': 'Wendy'},
#      'message': 'Set up basic graph',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/miaschoening1/ReconnectApp/commits/91761e045486a26569492bb16f014debd69abef9'},
#     {'sha': '4042ec86ba672e106194cbd4817a5e65a78b985a',
#      'author': {'email': 'wshi0810@gmail.com', 'name': 'Wendy'},
#      'message': 'Added to graph',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/miaschoening1/ReconnectApp/commits/4042ec86ba672e106194cbd4817a5e65a78b985a'},
#     {'sha': 'fef68fa9c7e3d6f3ac68559fb71bcc202aa2af93',
#      'author': {'email': 'wshi0810@gmail.com', 'name': 'Wendy'},
#      'message': 'Commented out unfinished code',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/miaschoening1/ReconnectApp/commits/fef68fa9c7e3d6f3ac68559fb71bcc202aa2af93'},
#     {'sha': '11ca8a2befd05491d9f24ec185788da314e2e290',
#      'author': {'email': 'wshi0810@gmail.com', 'name': 'Wendy'},
#      'message': 'Added icons and colors',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/miaschoening1/ReconnectApp/commits/11ca8a2befd05491d9f24ec185788da314e2e290'},
#     {'sha': '0e48f8957e20ee18c04256ee8baeed31bfdaad77',
#      'author': {'email': 'wshi0810@gmail.com', 'name': 'Wendy'},
#      'message': 'Finalized style and layout of summary, working on graph',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/miaschoening1/ReconnectApp/commits/0e48f8957e20ee18c04256ee8baeed31bfdaad77'},
#     {'sha': '7852438ffcdeeeac4a5ebd2612b107829adb046e',
#      'author': {'email': 'wshi0810@gmail.com', 'name': 'Wendy'},
#      'message': 'Updated graph',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/miaschoening1/ReconnectApp/commits/7852438ffcdeeeac4a5ebd2612b107829adb046e'},
#     {'sha': '2ee67e9135eb903bf838bd75e5d9e54f105907a0',
#      'author': {'email': 'wshi0810@gmail.com', 'name': 'Wendy'},
#      'message': 'Update graph again',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/miaschoening1/ReconnectApp/commits/2ee67e9135eb903bf838bd75e5d9e54f105907a0'},
#     {'sha': '973de68ecb3315edd0cbd04b876228df7ddd228f',
#      'author': {'email': 'wshi0810@gmail.com', 'name': 'Wendy Shi'},
#      'message': "Merge branch 'wendy' into master",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/miaschoening1/ReconnectApp/commits/973de68ecb3315edd0cbd04b876228df7ddd228f'}]},
#   'public': True,
#   'created_at': '2019-04-24T19:34:35Z'},
#  {'id': '9505016238',
#   'type': 'CreateEvent',
#   'actor': {'id': 41974937,
#    'login': 'elasticvolcano',
#    'display_login': 'elasticvolcano',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/elasticvolcano',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41974937?'},
#   'repo': {'id': 143081163,
#    'name': 'elasticvolcano/unicorn_api_proxy',
#    'url': 'https://api.github.com/repos/elasticvolcano/unicorn_api_proxy'},
#   'payload': {'ref': '2019-04-19-c7920364f6e8460a844c4a4bdbf1064b',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'An API which proxies API requests to another API',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-04-24T19:34:35Z'},
#  {'id': '9505016233',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 25149837,
#    'login': 'Florian-lg',
#    'display_login': 'Florian-lg',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Florian-lg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25149837?'},
#   'repo': {'id': 164025716,
#    'name': 'Anime-Reviewers-Society/Anime-Reviewers-Society',
#    'url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society'},
#   'payload': {'action': 'opened',
#    'number': 73,
#    'pull_request': {'url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/pulls/73',
#     'id': 273270444,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MjczMjcwNDQ0',
#     'html_url': 'https://github.com/Anime-Reviewers-Society/Anime-Reviewers-Society/pull/73',
#     'diff_url': 'https://github.com/Anime-Reviewers-Society/Anime-Reviewers-Society/pull/73.diff',
#     'patch_url': 'https://github.com/Anime-Reviewers-Society/Anime-Reviewers-Society/pull/73.patch',
#     'issue_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/issues/73',
#     'number': 73,
#     'state': 'open',
#     'locked': False,
#     'title': 'search form',
#     'user': {'login': 'Florian-lg',
#      'id': 25149837,
#      'node_id': 'MDQ6VXNlcjI1MTQ5ODM3',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/25149837?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Florian-lg',
#      'html_url': 'https://github.com/Florian-lg',
#      'followers_url': 'https://api.github.com/users/Florian-lg/followers',
#      'following_url': 'https://api.github.com/users/Florian-lg/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Florian-lg/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Florian-lg/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Florian-lg/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Florian-lg/orgs',
#      'repos_url': 'https://api.github.com/users/Florian-lg/repos',
#      'events_url': 'https://api.github.com/users/Florian-lg/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Florian-lg/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': "> ## ProTips:\r\n> \r\n> One of the key jobs of validating a pull request is running a series of tests to check that it won't break any existing work when merging in, and that the work that is does add actually... works. We can check this using a CI service like [Travis](https://travis-ci.org/getting_started). It allows people to know without having to wait for a team member to see if they have made any functional error in their code.\r\n\r\n# Pull Request Process\r\n\r\n## Before submitting a pull request\r\n\r\n> Ask contributors to ensure that any install or build dependencies are removed before the end of the layer when doing a build.\r\n\r\n## General steps for completing this pull request\r\n\r\nPlease review the [guidelines for contributing](CONTRIBUTING.md) to this repository.\r\n\r\n### Checklist\r\n\r\n> Does your project contributions have steps to follow before being approved? Tests, documentation changing, etc?\r\n\r\nEnsure that your `pull request` has followed all the steps below:\r\n\r\n- [ ] Code compilation\r\n- [ ] All tests passing\r\n- [ ] Extended the documentation, if applicable\r\n- [ ] Added myself to the AUTHORS file\r\n\r\n### Description\r\n\r\n> Ask the contributor to describe his `pull request`.\r\n\r\n## Proposed changes\r\n\r\n> Ask contributors about why you (or your project maintainers) would accept the pull request. If it solves a previous request, also ask to link to that issue.\r\n\r\n### Types of changes\r\n\r\n> Show in a checkbox-style, the expected types of changes your project is supposed to have:\r\n\r\n- [ ] New feature\r\n- [ ] Bugfix\r\n- [ ] So on...\r\n",
#     'created_at': '2019-04-24T19:34:35Z',
#     'updated_at': '2019-04-24T19:34:35Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/pulls/73/commits',
#     'review_comments_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/pulls/73/comments',
#     'review_comment_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/issues/73/comments',
#     'statuses_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/statuses/5cec162783b5c8c25bf95ec45aa224a19f8e490a',
#     'head': {'label': 'Anime-Reviewers-Society:ars/feature/search-form',
#      'ref': 'ars/feature/search-form',
#      'sha': '5cec162783b5c8c25bf95ec45aa224a19f8e490a',
#      'user': {'login': 'Anime-Reviewers-Society',
#       'id': 46358965,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ2MzU4OTY1',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/46358965?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Anime-Reviewers-Society',
#       'html_url': 'https://github.com/Anime-Reviewers-Society',
#       'followers_url': 'https://api.github.com/users/Anime-Reviewers-Society/followers',
#       'following_url': 'https://api.github.com/users/Anime-Reviewers-Society/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Anime-Reviewers-Society/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Anime-Reviewers-Society/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Anime-Reviewers-Society/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Anime-Reviewers-Society/orgs',
#       'repos_url': 'https://api.github.com/users/Anime-Reviewers-Society/repos',
#       'events_url': 'https://api.github.com/users/Anime-Reviewers-Society/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Anime-Reviewers-Society/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 164025716,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNjQwMjU3MTY=',
#       'name': 'Anime-Reviewers-Society',
#       'full_name': 'Anime-Reviewers-Society/Anime-Reviewers-Society',
#       'private': False,
#       'owner': {'login': 'Anime-Reviewers-Society',
#        'id': 46358965,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ2MzU4OTY1',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/46358965?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Anime-Reviewers-Society',
#        'html_url': 'https://github.com/Anime-Reviewers-Society',
#        'followers_url': 'https://api.github.com/users/Anime-Reviewers-Society/followers',
#        'following_url': 'https://api.github.com/users/Anime-Reviewers-Society/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Anime-Reviewers-Society/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Anime-Reviewers-Society/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Anime-Reviewers-Society/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Anime-Reviewers-Society/orgs',
#        'repos_url': 'https://api.github.com/users/Anime-Reviewers-Society/repos',
#        'events_url': 'https://api.github.com/users/Anime-Reviewers-Society/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Anime-Reviewers-Society/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/Anime-Reviewers-Society/Anime-Reviewers-Society',
#       'description': 'This repository contains the Anime Reviewers Society website',
#       'fork': False,
#       'url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society',
#       'forks_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/forks',
#       'keys_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/teams',
#       'hooks_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/events',
#       'assignees_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/tags',
#       'blobs_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/languages',
#       'stargazers_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/subscription',
#       'commits_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/merges',
#       'archive_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/downloads',
#       'issues_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/deployments',
#       'created_at': '2019-01-03T21:38:45Z',
#       'updated_at': '2019-04-24T12:32:23Z',
#       'pushed_at': '2019-04-24T19:31:30Z',
#       'git_url': 'git://github.com/Anime-Reviewers-Society/Anime-Reviewers-Society.git',
#       'ssh_url': 'git@github.com:Anime-Reviewers-Society/Anime-Reviewers-Society.git',
#       'clone_url': 'https://github.com/Anime-Reviewers-Society/Anime-Reviewers-Society.git',
#       'svn_url': 'https://github.com/Anime-Reviewers-Society/Anime-Reviewers-Society',
#       'homepage': 'http://anime-reviewers-society.com/',
#       'size': 2680,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'HTML',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 2,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 2,
#       'open_issues': 2,
#       'watchers': 0,
#       'default_branch': 'develop'}},
#     'base': {'label': 'Anime-Reviewers-Society:develop',
#      'ref': 'develop',
#      'sha': 'd0ecb1dae621a15df13b8ac2bf2da8e59245aeaa',
#      'user': {'login': 'Anime-Reviewers-Society',
#       'id': 46358965,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ2MzU4OTY1',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/46358965?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Anime-Reviewers-Society',
#       'html_url': 'https://github.com/Anime-Reviewers-Society',
#       'followers_url': 'https://api.github.com/users/Anime-Reviewers-Society/followers',
#       'following_url': 'https://api.github.com/users/Anime-Reviewers-Society/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Anime-Reviewers-Society/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Anime-Reviewers-Society/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Anime-Reviewers-Society/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Anime-Reviewers-Society/orgs',
#       'repos_url': 'https://api.github.com/users/Anime-Reviewers-Society/repos',
#       'events_url': 'https://api.github.com/users/Anime-Reviewers-Society/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Anime-Reviewers-Society/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 164025716,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNjQwMjU3MTY=',
#       'name': 'Anime-Reviewers-Society',
#       'full_name': 'Anime-Reviewers-Society/Anime-Reviewers-Society',
#       'private': False,
#       'owner': {'login': 'Anime-Reviewers-Society',
#        'id': 46358965,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ2MzU4OTY1',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/46358965?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Anime-Reviewers-Society',
#        'html_url': 'https://github.com/Anime-Reviewers-Society',
#        'followers_url': 'https://api.github.com/users/Anime-Reviewers-Society/followers',
#        'following_url': 'https://api.github.com/users/Anime-Reviewers-Society/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Anime-Reviewers-Society/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Anime-Reviewers-Society/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Anime-Reviewers-Society/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Anime-Reviewers-Society/orgs',
#        'repos_url': 'https://api.github.com/users/Anime-Reviewers-Society/repos',
#        'events_url': 'https://api.github.com/users/Anime-Reviewers-Society/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Anime-Reviewers-Society/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/Anime-Reviewers-Society/Anime-Reviewers-Society',
#       'description': 'This repository contains the Anime Reviewers Society website',
#       'fork': False,
#       'url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society',
#       'forks_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/forks',
#       'keys_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/teams',
#       'hooks_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/events',
#       'assignees_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/tags',
#       'blobs_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/languages',
#       'stargazers_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/subscription',
#       'commits_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/merges',
#       'archive_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/downloads',
#       'issues_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/deployments',
#       'created_at': '2019-01-03T21:38:45Z',
#       'updated_at': '2019-04-24T12:32:23Z',
#       'pushed_at': '2019-04-24T19:31:30Z',
#       'git_url': 'git://github.com/Anime-Reviewers-Society/Anime-Reviewers-Society.git',
#       'ssh_url': 'git@github.com:Anime-Reviewers-Society/Anime-Reviewers-Society.git',
#       'clone_url': 'https://github.com/Anime-Reviewers-Society/Anime-Reviewers-Society.git',
#       'svn_url': 'https://github.com/Anime-Reviewers-Society/Anime-Reviewers-Society',
#       'homepage': 'http://anime-reviewers-society.com/',
#       'size': 2680,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'HTML',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 2,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 2,
#       'open_issues': 2,
#       'watchers': 0,
#       'default_branch': 'develop'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/pulls/73'},
#      'html': {'href': 'https://github.com/Anime-Reviewers-Society/Anime-Reviewers-Society/pull/73'},
#      'issue': {'href': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/issues/73'},
#      'comments': {'href': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/issues/73/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/pulls/73/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/pulls/73/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/Anime-Reviewers-Society/Anime-Reviewers-Society/statuses/5cec162783b5c8c25bf95ec45aa224a19f8e490a'}},
#     'author_association': 'MEMBER',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 114,
#     'deletions': 27,
#     'changed_files': 11}},
#   'public': True,
#   'created_at': '2019-04-24T19:34:35Z',
#   'org': {'id': 46358965,
#    'login': 'Anime-Reviewers-Society',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Anime-Reviewers-Society',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46358965?'}},
#  {'id': '9505016232',
#   'type': 'IssuesEvent',
#   'actor': {'id': 49042670,
#    'login': 'rezamahdiani',
#    'display_login': 'rezamahdiani',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rezamahdiani',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49042670?'},
#   'repo': {'id': 125074390,
#    'name': 'BlueMetal/iot-edge-dynocard',
#    'url': 'https://api.github.com/repos/BlueMetal/iot-edge-dynocard'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/BlueMetal/iot-edge-dynocard/issues/5',
#     'repository_url': 'https://api.github.com/repos/BlueMetal/iot-edge-dynocard',
#     'labels_url': 'https://api.github.com/repos/BlueMetal/iot-edge-dynocard/issues/5/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/BlueMetal/iot-edge-dynocard/issues/5/comments',
#     'events_url': 'https://api.github.com/repos/BlueMetal/iot-edge-dynocard/issues/5/events',
#     'html_url': 'https://github.com/BlueMetal/iot-edge-dynocard/issues/5',
#     'id': 436870442,
#     'node_id': 'MDU6SXNzdWU0MzY4NzA0NDI=',
#     'number': 5,
#     'title': 'wrong visualization',
#     'user': {'login': 'rezamahdiani',
#      'id': 49042670,
#      'node_id': 'MDQ6VXNlcjQ5MDQyNjcw',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/49042670?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/rezamahdiani',
#      'html_url': 'https://github.com/rezamahdiani',
#      'followers_url': 'https://api.github.com/users/rezamahdiani/followers',
#      'following_url': 'https://api.github.com/users/rezamahdiani/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/rezamahdiani/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/rezamahdiani/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/rezamahdiani/subscriptions',
#      'organizations_url': 'https://api.github.com/users/rezamahdiani/orgs',
#      'repos_url': 'https://api.github.com/users/rezamahdiani/repos',
#      'events_url': 'https://api.github.com/users/rezamahdiani/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/rezamahdiani/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2019-04-24T19:34:35Z',
#     'updated_at': '2019-04-24T19:34:35Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'body': "Hi\r\nI used this tutorial but I don't see the correct visualization I see some thing as below what should I do:\r\n\r\n![Capture](https://user-images.githubusercontent.com/49042670/56688328-acfe0680-6695-11e9-9732-a42018c09b5d.PNG)\r\n"}},
#   'public': True,
#   'created_at': '2019-04-24T19:34:35Z',
#   'org': {'id': 1541308,
#    'login': 'BlueMetal',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/BlueMetal',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1541308?'}},
#  {'id': '9505016217',
#   'type': 'PushEvent',
#   'actor': {'id': 650502,
#    'login': 'Danielhiversen',
#    'display_login': 'Danielhiversen',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Danielhiversen',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/650502?'},
#   'repo': {'id': 12888993,
#    'name': 'home-assistant/home-assistant',
#    'url': 'https://api.github.com/repos/home-assistant/home-assistant'},
#   'payload': {'push_id': 3542382592,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/ambiclimate',
#    'head': 'a37920fc44d3b21a5ddc933a14b7f1d3d5b9cf06',
#    'before': '5b156245743fd9dd2840b4ba91a2d2d447bbd48d',
#    'commits': [{'sha': 'a37920fc44d3b21a5ddc933a14b7f1d3d5b9cf06',
#      'author': {'email': 'Daniel.Iversen@tibber.com',
#       'name': 'Daniel Høyer Iversen'},
#      'message': 'tests',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/home-assistant/home-assistant/commits/a37920fc44d3b21a5ddc933a14b7f1d3d5b9cf06'}]},
#   'public': True,
#   'created_at': '2019-04-24T19:34:35Z',
#   'org': {'id': 13844975,
#    'login': 'home-assistant',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/home-assistant',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13844975?'}},
#  {'id': '9505016226',
#   'type': 'ForkEvent',
#   'actor': {'id': 49959625,
#    'login': 'holassan',
#    'display_login': 'holassan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/holassan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49959625?'},
#   'repo': {'id': 26195776,
#    'name': 'JedWatson/classnames',
#    'url': 'https://api.github.com/repos/JedWatson/classnames'},
#   'payload': {'forkee': {'id': 183294788,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkxODMyOTQ3ODg=',
#     'name': 'classnames',
#     'full_name': 'holassan/classnames',
#     'private': False,
#     'owner': {'login': 'holassan',
#      'id': 49959625,
#      'node_id': 'MDQ6VXNlcjQ5OTU5NjI1',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/49959625?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/holassan',
#      'html_url': 'https://github.com/holassan',
#      'followers_url': 'https://api.github.com/users/holassan/followers',
#      'following_url': 'https://api.github.com/users/holassan/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/holassan/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/holassan/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/holassan/subscriptions',
#      'organizations_url': 'https://api.github.com/users/holassan/orgs',
#      'repos_url': 'https://api.github.com/users/holassan/repos',
#      'events_url': 'https://api.github.com/users/holassan/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/holassan/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/holassan/classnames',
#     'description': 'A simple javascript utility for conditionally joining classNames together',
#     'fork': True,
#     'url': 'https://api.github.com/repos/holassan/classnames',
#     'forks_url': 'https://api.github.com/repos/holassan/classnames/forks',
#     'keys_url': 'https://api.github.com/repos/holassan/classnames/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/holassan/classnames/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/holassan/classnames/teams',
#     'hooks_url': 'https://api.github.com/repos/holassan/classnames/hooks',
#     'issue_events_url': 'https://api.github.com/repos/holassan/classnames/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/holassan/classnames/events',
#     'assignees_url': 'https://api.github.com/repos/holassan/classnames/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/holassan/classnames/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/holassan/classnames/tags',
#     'blobs_url': 'https://api.github.com/repos/holassan/classnames/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/holassan/classnames/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/holassan/classnames/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/holassan/classnames/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/holassan/classnames/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/holassan/classnames/languages',
#     'stargazers_url': 'https://api.github.com/repos/holassan/classnames/stargazers',
#     'contributors_url': 'https://api.github.com/repos/holassan/classnames/contributors',
#     'subscribers_url': 'https://api.github.com/repos/holassan/classnames/subscribers',
#     'subscription_url': 'https://api.github.com/repos/holassan/classnames/subscription',
#     'commits_url': 'https://api.github.com/repos/holassan/classnames/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/holassan/classnames/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/holassan/classnames/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/holassan/classnames/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/holassan/classnames/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/holassan/classnames/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/holassan/classnames/merges',
#     'archive_url': 'https://api.github.com/repos/holassan/classnames/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/holassan/classnames/downloads',
#     'issues_url': 'https://api.github.com/repos/holassan/classnames/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/holassan/classnames/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/holassan/classnames/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/holassan/classnames/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/holassan/classnames/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/holassan/classnames/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/holassan/classnames/deployments',
#     'created_at': '2019-04-24T19:34:35Z',
#     'updated_at': '2019-04-24T19:34:34Z',
#     'pushed_at': '2019-04-13T09:31:40Z',
#     'git_url': 'git://github.com/holassan/classnames.git',
#     'ssh_url': 'git@github.com:holassan/classnames.git',
#     'clone_url': 'https://github.com/holassan/classnames.git',
#     'svn_url': 'https://github.com/holassan/classnames',
#     'homepage': None,
#     'size': 171,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2019-04-24T19:34:35Z'},
#  {'id': '9505016215',
#   'type': 'PushEvent',
#   'actor': {'id': 36632319,
#    'login': 'Piratedreams',
#    'display_login': 'Piratedreams',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Piratedreams',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/36632319?'},
#   'repo': {'id': 183103938,
#    'name': 'Piratedreams/Runaround',
#    'url': 'https://api.github.com/repos/Piratedreams/Runaround'},
#   'payload': {'push_id': 3542382593,
#    'size': 3,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'd1ad360e669c0753d72b439725cdeac9e2501853',
#    'before': '40b87342f23232e7133e09f7bebd815881e406aa',
#    'commits': [{'sha': 'a6247e968c0a805a874b746c8cfae735532634d5',
#      'author': {'email': 'buckets_truong@Daviss-MacBook-Pro.local',
#       'name': 'Davis Truong'},
#      'message': 'errs',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Piratedreams/Runaround/commits/a6247e968c0a805a874b746c8cfae735532634d5'},
#     {'sha': 'b0c081f9c10701014b602fb92a67508cb95e1430',
#      'author': {'email': '48306562+bucket-truong@users.noreply.github.com',
#       'name': 'bucket-truong'},
#      'message': "Merge branch 'master' into davis",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Piratedreams/Runaround/commits/b0c081f9c10701014b602fb92a67508cb95e1430'},
#     {'sha': 'd1ad360e669c0753d72b439725cdeac9e2501853',
#      'author': {'email': '36632319+Piratedreams@users.noreply.github.com',
#       'name': 'Ben Wall'},
#      'message': 'Merge pull request #8 from Piratedreams/davis\n\nerrs',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Piratedreams/Runaround/commits/d1ad360e669c0753d72b439725cdeac9e2501853'}]},
#   'public': True,
#   'created_at': '2019-04-24T19:34:35Z'},
#  {'id': '9505016213',
#   'type': 'PushEvent',
#   'actor': {'id': 254448,
#    'login': 'jpereira',
#    'display_login': 'jpereira',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jpereira',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/254448?'},
#   'repo': {'id': 34817472,
#    'name': 'jpereira/freeradius-server',
#    'url': 'https://api.github.com/repos/jpereira/freeradius-server'},
#   'payload': {'push_id': 3542382594,
#    'size': 30,
#    'distinct_size': 30,
#    'ref': 'refs/heads/master',
#    'head': 'd825e1c98e06ddd08f10377baaffd12824233a67',
#    'before': '43abec7e4361fbe9d0dff06b2dcdc49487cfe420',
#    'commits': [{'sha': '36195b8a168c6ef277291004896d3aff0eaf4706',
#      'author': {'email': 'jpereiran@gmail.com', 'name': 'Jorge Pereira'},
#      'message': 'Fix listen.ipaddr to reference an IPv6-only host #2627',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jpereira/freeradius-server/commits/36195b8a168c6ef277291004896d3aff0eaf4706'},
#     {'sha': 'fffbd4b2b0dc022e3eee40581493cabe096b5dc5',
#      'author': {'email': 'jpereiran@gmail.com', 'name': 'Jorge Pereira'},
#      'message': 'Fix isnan() issue with clang 7.0.x',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jpereira/freeradius-server/commits/fffbd4b2b0dc022e3eee40581493cabe096b5dc5'},
#     {'sha': 'ec75496163debf66afc2ef374f7f2e9514492451',
#      'author': {'email': 'a.cudbardb@freeradius.org',
#       'name': 'Arran Cudbard-Bell'},
#      'message': 'Fix leak and cosmetic issue in log output',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jpereira/freeradius-server/commits/ec75496163debf66afc2ef374f7f2e9514492451'},
#     {'sha': '8d363cdbee2fad77469026ce3eb18030aecc9b0f',
#      'author': {'email': 'a.cudbardb@freeradius.org',
#       'name': 'Arran Cudbard-Bell'},
#      'message': "Don't segv if instance is NULL",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jpereira/freeradius-server/commits/8d363cdbee2fad77469026ce3eb18030aecc9b0f'},
#     {'sha': 'af963d45af611f5237732c69fa7eb5468c83a94a',
#      'author': {'email': 'a.cudbardb@freeradius.org',
#       'name': 'Arran Cudbard-Bell'},
#      'message': 'Switch eap method functions to module_method_t to allow async calling',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jpereira/freeradius-server/commits/af963d45af611f5237732c69fa7eb5468c83a94a'},
#     {'sha': '33ed8a76bed92c81d61712ec2c8ee97793679849',
#      'author': {'email': 'a.cudbardb@freeradius.org',
#       'name': 'Arran Cudbard-Bell'},
#      'message': 'Doxygen',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jpereira/freeradius-server/commits/33ed8a76bed92c81d61712ec2c8ee97793679849'},
#     {'sha': '841e4c7c69a4d202393fa74d542a672770a27ef9',
#      'author': {'email': 'a.cudbardb@freeradius.org',
#       'name': 'Arran Cudbard-Bell'},
#      'message': 'Doxygen',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jpereira/freeradius-server/commits/841e4c7c69a4d202393fa74d542a672770a27ef9'},
#     {'sha': '022cdf139f2f2314f513d59ae7040672c97398f2',
#      'author': {'email': 'a.cudbardb@freeradius.org',
#       'name': 'Arran Cudbard-Bell'},
#      'message': 'rcode not needed',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jpereira/freeradius-server/commits/022cdf139f2f2314f513d59ae7040672c97398f2'},
#     {'sha': '6abede80d2b53888bd0bc54a4f47569fead58f71',
#      'author': {'email': 'a.cudbardb@freeradius.org',
#       'name': 'Arran Cudbard-Bell'},
#      'message': 'Fix eap fast private data allocation',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jpereira/freeradius-server/commits/6abede80d2b53888bd0bc54a4f47569fead58f71'},
#     {'sha': '3149f875fcd87a71aaa956c50ab4fe7bac4cc3d3',
#      'author': {'email': 'aland@freeradius.org', 'name': 'Alan T. DeKok'},
#      'message': 'add pandoc / asciidoc to configure checks.  Fixes #2622',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jpereira/freeradius-server/commits/3149f875fcd87a71aaa956c50ab4fe7bac4cc3d3'},
#     {'sha': '9f6604d3ba7e1b80fc7abdd42142c279ed0ca30f',
#      'author': {'email': 'aland@freeradius.org', 'name': 'Alan T. DeKok'},
#      'message': 'auto-select UPDATE action for DHCP-Request',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jpereira/freeradius-server/commits/9f6604d3ba7e1b80fc7abdd42142c279ed0ca30f'},
#     {'sha': '721b0f91c70756d4bbbf009293226bcd643dff38',
#      'author': {'email': 'aland@freeradius.org', 'name': 'Alan T. DeKok'},
#      'message': 'typo',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jpereira/freeradius-server/commits/721b0f91c70756d4bbbf009293226bcd643dff38'},
#     {'sha': '32f534cb7d532704c5b0fc8aff19e26948798329',
#      'author': {'email': 'a.cudbardb@freeradius.org',
#       'name': 'Arran Cudbard-Bell'},
#      'message': "Apparently eap_fast_tunnel_t isn't used in mod_process",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jpereira/freeradius-server/commits/32f534cb7d532704c5b0fc8aff19e26948798329'},
#     {'sha': 'c96ba3f08ae2ed8e8e80d3f33638e4fd9fd2c59b',
#      'author': {'email': 'a.cudbardb@freeradius.org',
#       'name': 'Arran Cudbard-Bell'},
#      'message': '*sigh*',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jpereira/freeradius-server/commits/c96ba3f08ae2ed8e8e80d3f33638e4fd9fd2c59b'},
#     {'sha': 'c8cba4fe49ac12bc4fbf155738d3fca948d09f69',
#      'author': {'email': 'aland@freeradius.org', 'name': 'Alan T. DeKok'},
#      'message': 'check for compatible dictionaries\n\nwhen doing cross-server calls',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jpereira/freeradius-server/commits/c8cba4fe49ac12bc4fbf155738d3fca948d09f69'},
#     {'sha': '0823a64a239eb9674fcfff9beb3c13c2e8f2f945',
#      'author': {'email': 'a.cudbardb@freeradius.org',
#       'name': 'Arran Cudbard-Bell'},
#      'message': 'Not storing ASN1 strings',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jpereira/freeradius-server/commits/0823a64a239eb9674fcfff9beb3c13c2e8f2f945'},
#     {'sha': 'e424ea3f4d82eaed5d12af95c7deb5391edb9541',
#      'author': {'email': 'a.cudbardb@freeradius.org',
#       'name': 'Arran Cudbard-Bell'},
#      'message': 'Add case insensitive matching for more things in the default OpenLDAP schema addresses #1003',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jpereira/freeradius-server/commits/e424ea3f4d82eaed5d12af95c7deb5391edb9541'},
#     {'sha': '918f9ef897ee8d5dcce31ba49538aebd7c324d80',
#      'author': {'email': 'a.cudbardb@freeradius.org',
#       'name': 'Arran Cudbard-Bell'},
#      'message': 'Alc-Client-Hardware-Addr is a string not an ethernet address',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jpereira/freeradius-server/commits/918f9ef897ee8d5dcce31ba49538aebd7c324d80'},
#     {'sha': '204ad28b7585d17f9e79e9dbfb3686e7f5eda63f',
#      'author': {'email': 'aland@freeradius.org', 'name': 'Alan T. DeKok'},
# ...
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Reverts EriCoursin/lukysQuest#19',
#     'created_at': '2019-04-24T19:34:34Z',
#     'updated_at': '2019-04-24T19:34:34Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/pulls/20/commits',
#     'review_comments_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/pulls/20/comments',
#     'review_comment_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/issues/20/comments',
#     'statuses_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/statuses/80b8b554cc947e654489668f58ac3ac31360d7ff',
#     'head': {'label': 'EriCoursin:revert-19-Added-heart',
#      'ref': 'revert-19-Added-heart',
#      'sha': '80b8b554cc947e654489668f58ac3ac31360d7ff',
#      'user': {'login': 'EriCoursin',
#       'id': 35472972,
#       'node_id': 'MDQ6VXNlcjM1NDcyOTcy',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/35472972?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/EriCoursin',
#       'html_url': 'https://github.com/EriCoursin',
#       'followers_url': 'https://api.github.com/users/EriCoursin/followers',
#       'following_url': 'https://api.github.com/users/EriCoursin/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/EriCoursin/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/EriCoursin/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/EriCoursin/subscriptions',
#       'organizations_url': 'https://api.github.com/users/EriCoursin/orgs',
#       'repos_url': 'https://api.github.com/users/EriCoursin/repos',
#       'events_url': 'https://api.github.com/users/EriCoursin/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/EriCoursin/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 180859304,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxODA4NTkzMDQ=',
#       'name': 'lukysQuest',
#       'full_name': 'EriCoursin/lukysQuest',
#       'private': False,
#       'owner': {'login': 'EriCoursin',
#        'id': 35472972,
#        'node_id': 'MDQ6VXNlcjM1NDcyOTcy',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/35472972?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/EriCoursin',
#        'html_url': 'https://github.com/EriCoursin',
#        'followers_url': 'https://api.github.com/users/EriCoursin/followers',
#        'following_url': 'https://api.github.com/users/EriCoursin/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/EriCoursin/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/EriCoursin/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/EriCoursin/subscriptions',
#        'organizations_url': 'https://api.github.com/users/EriCoursin/orgs',
#        'repos_url': 'https://api.github.com/users/EriCoursin/repos',
#        'events_url': 'https://api.github.com/users/EriCoursin/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/EriCoursin/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/EriCoursin/lukysQuest',
#       'description': 'APCSP Create Task - Made in GameMaker',
#       'fork': False,
#       'url': 'https://api.github.com/repos/EriCoursin/lukysQuest',
#       'forks_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/forks',
#       'keys_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/teams',
#       'hooks_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/hooks',
#       'issue_events_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/events',
#       'assignees_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/tags',
#       'blobs_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/languages',
#       'stargazers_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/stargazers',
#       'contributors_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/contributors',
#       'subscribers_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/subscribers',
#       'subscription_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/subscription',
#       'commits_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/merges',
#       'archive_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/downloads',
#       'issues_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/deployments',
#       'created_at': '2019-04-11T19:00:13Z',
#       'updated_at': '2019-04-24T19:33:55Z',
#       'pushed_at': '2019-04-24T19:34:26Z',
#       'git_url': 'git://github.com/EriCoursin/lukysQuest.git',
#       'ssh_url': 'git@github.com:EriCoursin/lukysQuest.git',
#       'clone_url': 'https://github.com/EriCoursin/lukysQuest.git',
#       'svn_url': 'https://github.com/EriCoursin/lukysQuest',
#       'homepage': None,
#       'size': 91,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Game Maker Language',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'EriCoursin:master',
#      'ref': 'master',
#      'sha': 'f6d4b27bab97f1dce61abeceea996025ac895a94',
#      'user': {'login': 'EriCoursin',
#       'id': 35472972,
#       'node_id': 'MDQ6VXNlcjM1NDcyOTcy',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/35472972?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/EriCoursin',
#       'html_url': 'https://github.com/EriCoursin',
#       'followers_url': 'https://api.github.com/users/EriCoursin/followers',
#       'following_url': 'https://api.github.com/users/EriCoursin/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/EriCoursin/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/EriCoursin/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/EriCoursin/subscriptions',
#       'organizations_url': 'https://api.github.com/users/EriCoursin/orgs',
#       'repos_url': 'https://api.github.com/users/EriCoursin/repos',
#       'events_url': 'https://api.github.com/users/EriCoursin/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/EriCoursin/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 180859304,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxODA4NTkzMDQ=',
#       'name': 'lukysQuest',
#       'full_name': 'EriCoursin/lukysQuest',
#       'private': False,
#       'owner': {'login': 'EriCoursin',
#        'id': 35472972,
#        'node_id': 'MDQ6VXNlcjM1NDcyOTcy',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/35472972?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/EriCoursin',
#        'html_url': 'https://github.com/EriCoursin',
#        'followers_url': 'https://api.github.com/users/EriCoursin/followers',
#        'following_url': 'https://api.github.com/users/EriCoursin/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/EriCoursin/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/EriCoursin/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/EriCoursin/subscriptions',
#        'organizations_url': 'https://api.github.com/users/EriCoursin/orgs',
#        'repos_url': 'https://api.github.com/users/EriCoursin/repos',
#        'events_url': 'https://api.github.com/users/EriCoursin/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/EriCoursin/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/EriCoursin/lukysQuest',
#       'description': 'APCSP Create Task - Made in GameMaker',
#       'fork': False,
#       'url': 'https://api.github.com/repos/EriCoursin/lukysQuest',
#       'forks_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/forks',
#       'keys_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/teams',
#       'hooks_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/hooks',
#       'issue_events_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/events',
#       'assignees_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/tags',
#       'blobs_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/languages',
#       'stargazers_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/stargazers',
#       'contributors_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/contributors',
#       'subscribers_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/subscribers',
#       'subscription_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/subscription',
#       'commits_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/merges',
#       'archive_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/downloads',
#       'issues_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/EriCoursin/lukysQuest/deployments',
#       'created_at': '2019-04-11T19:00:13Z',
#       'updated_at': '2019-04-24T19:33:55Z',
#       'pushed_at': '2019-04-24T19:34:26Z',
#       'git_url': 'git://github.com/EriCoursin/lukysQuest.git',
#       'ssh_url': 'git@github.com:EriCoursin/lukysQuest.git',
#       'clone_url': 'https://github.com/EriCoursin/lukysQuest.git',
#       'svn_url': 'https://github.com/EriCoursin/lukysQuest',
#       'homepage': None,
#       'size': 91,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Game Maker Language',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/EriCoursin/lukysQuest/pulls/20'},
#      'html': {'href': 'https://github.com/EriCoursin/lukysQuest/pull/20'},
#      'issue': {'href': 'https://api.github.com/repos/EriCoursin/lukysQuest/issues/20'},
#      'comments': {'href': 'https://api.github.com/repos/EriCoursin/lukysQuest/issues/20/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/EriCoursin/lukysQuest/pulls/20/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/EriCoursin/lukysQuest/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/EriCoursin/lukysQuest/pulls/20/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/EriCoursin/lukysQuest/statuses/80b8b554cc947e654489668f58ac3ac31360d7ff'}},
#     'author_association': 'OWNER',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 12,
#     'deletions': 515,
#     'changed_files': 9}},
#   'public': True,
#   'created_at': '2019-04-24T19:34:34Z'}]

# %%
'''
Knowing the data is a list, we can access index 0 for the first
element of the list.
'''
r.json()[0]
# Out:
# {'id': '9505016235',
#  'type': 'PushEvent',
#  'actor': {'id': 15008142,
#   'login': 'wenxuans',
#   'display_login': 'wenxuans',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/wenxuans',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/15008142?'},
#  'repo': {'id': 178074109,
#   'name': 'miaschoening1/ReconnectApp',
#   'url': 'https://api.github.com/repos/miaschoening1/ReconnectApp'},
#  'payload': {'push_id': 3542382603,
#   'size': 12,
#   'distinct_size': 1,
#   'ref': 'refs/heads/master',
#   'head': '973de68ecb3315edd0cbd04b876228df7ddd228f',
#   'before': 'db41bd712d69aebe082ecd76fe287ed43115d9ba',
#   'commits': [{'sha': 'd7392cea71239bb960cecd17e9607ad938653039',
#     'author': {'email': 'wshi0810@gmail.com', 'name': 'Wendy'},
#     'message': 'Set up Summary activity',
#     'distinct': False,
#     'url': 'https://api.github.com/repos/miaschoening1/ReconnectApp/commits/d7392cea71239bb960cecd17e9607ad938653039'},
#    {'sha': 'f3528b6a0dc72343d7863e81ecc8361a961e18ce',
#     'author': {'email': 'wshi0810@gmail.com', 'name': 'Wendy'},
#     'message': "Merge branch 'mia' of https://github.com/miaschoening1/ReconnectApp into wendy",
#     'distinct': False,
#     'url': 'https://api.github.com/repos/miaschoening1/ReconnectApp/commits/f3528b6a0dc72343d7863e81ecc8361a961e18ce'},
#    {'sha': 'ee90968003b9f9a2b7f32990fe78588766e9bfd4',
#     'author': {'email': 'wshi0810@gmail.com', 'name': 'Wendy'},
#     'message': 'Set up Summary layout',
#     'distinct': False,
#     'url': 'https://api.github.com/repos/miaschoening1/ReconnectApp/commits/ee90968003b9f9a2b7f32990fe78588766e9bfd4'},
#    {'sha': 'de801f0403a4dd8fff644bdc8de30843e57369fc',
#     'author': {'email': 'wshi0810@gmail.com', 'name': 'Wendy'},
#     'message': 'Added dropdown style',
#     'distinct': False,
#     'url': 'https://api.github.com/repos/miaschoening1/ReconnectApp/commits/de801f0403a4dd8fff644bdc8de30843e57369fc'},
#    {'sha': '91761e045486a26569492bb16f014debd69abef9',
#     'author': {'email': 'wshi0810@gmail.com', 'name': 'Wendy'},
#     'message': 'Set up basic graph',
#     'distinct': False,
#     'url': 'https://api.github.com/repos/miaschoening1/ReconnectApp/commits/91761e045486a26569492bb16f014debd69abef9'},
#    {'sha': '4042ec86ba672e106194cbd4817a5e65a78b985a',
#     'author': {'email': 'wshi0810@gmail.com', 'name': 'Wendy'},
#     'message': 'Added to graph',
#     'distinct': False,
#     'url': 'https://api.github.com/repos/miaschoening1/ReconnectApp/commits/4042ec86ba672e106194cbd4817a5e65a78b985a'},
#    {'sha': 'fef68fa9c7e3d6f3ac68559fb71bcc202aa2af93',
#     'author': {'email': 'wshi0810@gmail.com', 'name': 'Wendy'},
#     'message': 'Commented out unfinished code',
#     'distinct': False,
#     'url': 'https://api.github.com/repos/miaschoening1/ReconnectApp/commits/fef68fa9c7e3d6f3ac68559fb71bcc202aa2af93'},
#    {'sha': '11ca8a2befd05491d9f24ec185788da314e2e290',
#     'author': {'email': 'wshi0810@gmail.com', 'name': 'Wendy'},
#     'message': 'Added icons and colors',
#     'distinct': False,
#     'url': 'https://api.github.com/repos/miaschoening1/ReconnectApp/commits/11ca8a2befd05491d9f24ec185788da314e2e290'},
#    {'sha': '0e48f8957e20ee18c04256ee8baeed31bfdaad77',
#     'author': {'email': 'wshi0810@gmail.com', 'name': 'Wendy'},
#     'message': 'Finalized style and layout of summary, working on graph',
#     'distinct': False,
#     'url': 'https://api.github.com/repos/miaschoening1/ReconnectApp/commits/0e48f8957e20ee18c04256ee8baeed31bfdaad77'},
#    {'sha': '7852438ffcdeeeac4a5ebd2612b107829adb046e',
#     'author': {'email': 'wshi0810@gmail.com', 'name': 'Wendy'},
#     'message': 'Updated graph',
#     'distinct': False,
#     'url': 'https://api.github.com/repos/miaschoening1/ReconnectApp/commits/7852438ffcdeeeac4a5ebd2612b107829adb046e'},
#    {'sha': '2ee67e9135eb903bf838bd75e5d9e54f105907a0',
#     'author': {'email': 'wshi0810@gmail.com', 'name': 'Wendy'},
#     'message': 'Update graph again',
#     'distinct': False,
#     'url': 'https://api.github.com/repos/miaschoening1/ReconnectApp/commits/2ee67e9135eb903bf838bd75e5d9e54f105907a0'},
#    {'sha': '973de68ecb3315edd0cbd04b876228df7ddd228f',
#     'author': {'email': 'wshi0810@gmail.com', 'name': 'Wendy Shi'},
#     'message': "Merge branch 'wendy' into master",
#     'distinct': True,
#     'url': 'https://api.github.com/repos/miaschoening1/ReconnectApp/commits/973de68ecb3315edd0cbd04b876228df7ddd228f'}]},
#  'public': True,
#  'created_at': '2019-04-24T19:34:35Z'}

# %%
'''
Knowing that each element in the list is a dictionary we can access
it via the dictionary key.

Enumerage the login name of user (actor) mentioned above.
'''
r.json()[0]['actor']['login']
# Out:
# 'wenxuans'

# %%
'''
You now have enough pieces to query multiple aspects of the data.
I'd like you to get three fields out of each element in the json()
list from our initial GET request.

The username: This is the 'login' key/value pair under the 'actor' key
The repo URL: This is the 'name' key/value pair under the 'repo' key
The entry time: This is the 'created_at' key

Hint: The repo URL can be shown by concatenating the github URL and name
like shown below:

'https://github.com/' + entry['repo']['name']

'''
cwd = os.path.abspath('.')
with open(os.path.join(cwd, "api_output.csv"), 'w+') as csvfile:
    csvwriter = csv.writer(csvfile, lineterminator = '\n')
    # Get a csv object to write to (hint use ATBS chapter 14)
    # NOT IMPLEMENTED YET, you need to set 'csvwriter = ... something ...")
    
    # Write out a header line
    # NOT IMPLEMENTED YET, easy one, just uncomment below and delete me")
    header = ['USERNAME', 'REPO_URL', 'ENTRY_TIME']
    csvwriter.writerow(header)
    
    # Write out each entry with the portions we care about into the CSV
    for entry in r.json():
        csvwriter.writerow([entry['actor']['login'], 'https://github.com/' + 
                           entry['repo']['name'], entry['created_at']])
        # NOT IMPLEMENTED YET, use writerow of the three fields
        # mentioned above into the CSV file

# %% [markdown]
# Alright, you got the gist of things now. Your next step is to identify
# an API that you would like to interact with. Write some code to make a
# query, inspect that result, and selectively pull out some information
# you find interesting from it.
#
# Many sites require an API key to retrive data. Even something as innocuous as a request to get the weather can be abused by someone
# looking to get something for free. You can find a list of sites below
# that offer a free unauthenticated API.
#
# https://shkspr.mobi/blog/2016/05/easy-apis-without-authentication/
#
# If you can't think of anything interesting here's two ideas, an easy
# one and a harder one where you'll have to do a bit of research:
#
# 1. Query all Star Wars universe planets, inspect the raw data, note
#    that the planets list different climates so iterate through the
#    list of planets and only show the name of planets with 'temperate'
#    in the 'climate' key. Use a requests GET on the following URL to
#    get you started:
#
#    https://swapi.co/api/planets/
#
# 2. Query the Google books API documented at the below link and show
#    a summary of your most recent book.
#
#    https://developers.google.com/books/

# %%
'''
NOT IMPLEMENTED YET - make it happen!
'''

r = requests.get('https://swapi.co/api/planets/')

# %%
r.json()
# Out:
# {'count': 61,
#  'next': 'https://swapi.co/api/planets/?page=2',
#  'previous': None,
#  'results': [{'name': 'Alderaan',
#    'rotation_period': '24',
#    'orbital_period': '364',
#    'diameter': '12500',
#    'climate': 'temperate',
#    'gravity': '1 standard',
#    'terrain': 'grasslands, mountains',
#    'surface_water': '40',
#    'population': '2000000000',
#    'residents': ['https://swapi.co/api/people/5/',
#     'https://swapi.co/api/people/68/',
#     'https://swapi.co/api/people/81/'],
#    'films': ['https://swapi.co/api/films/6/', 'https://swapi.co/api/films/1/'],
#    'created': '2014-12-10T11:35:48.479000Z',
#    'edited': '2014-12-20T20:58:18.420000Z',
#    'url': 'https://swapi.co/api/planets/2/'},
#   {'name': 'Yavin IV',
#    'rotation_period': '24',
#    'orbital_period': '4818',
#    'diameter': '10200',
#    'climate': 'temperate, tropical',
#    'gravity': '1 standard',
#    'terrain': 'jungle, rainforests',
#    'surface_water': '8',
#    'population': '1000',
#    'residents': [],
#    'films': ['https://swapi.co/api/films/1/'],
#    'created': '2014-12-10T11:37:19.144000Z',
#    'edited': '2014-12-20T20:58:18.421000Z',
#    'url': 'https://swapi.co/api/planets/3/'},
#   {'name': 'Hoth',
#    'rotation_period': '23',
#    'orbital_period': '549',
#    'diameter': '7200',
#    'climate': 'frozen',
#    'gravity': '1.1 standard',
#    'terrain': 'tundra, ice caves, mountain ranges',
#    'surface_water': '100',
#    'population': 'unknown',
#    'residents': [],
#    'films': ['https://swapi.co/api/films/2/'],
#    'created': '2014-12-10T11:39:13.934000Z',
#    'edited': '2014-12-20T20:58:18.423000Z',
#    'url': 'https://swapi.co/api/planets/4/'},
#   {'name': 'Dagobah',
#    'rotation_period': '23',
#    'orbital_period': '341',
#    'diameter': '8900',
#    'climate': 'murky',
#    'gravity': 'N/A',
#    'terrain': 'swamp, jungles',
#    'surface_water': '8',
#    'population': 'unknown',
#    'residents': [],
#    'films': ['https://swapi.co/api/films/2/',
#     'https://swapi.co/api/films/6/',
#     'https://swapi.co/api/films/3/'],
#    'created': '2014-12-10T11:42:22.590000Z',
#    'edited': '2014-12-20T20:58:18.425000Z',
#    'url': 'https://swapi.co/api/planets/5/'},
#   {'name': 'Bespin',
#    'rotation_period': '12',
#    'orbital_period': '5110',
#    'diameter': '118000',
#    'climate': 'temperate',
#    'gravity': '1.5 (surface), 1 standard (Cloud City)',
#    'terrain': 'gas giant',
#    'surface_water': '0',
#    'population': '6000000',
#    'residents': ['https://swapi.co/api/people/26/'],
#    'films': ['https://swapi.co/api/films/2/'],
#    'created': '2014-12-10T11:43:55.240000Z',
#    'edited': '2014-12-20T20:58:18.427000Z',
#    'url': 'https://swapi.co/api/planets/6/'},
#   {'name': 'Endor',
#    'rotation_period': '18',
#    'orbital_period': '402',
#    'diameter': '4900',
#    'climate': 'temperate',
#    'gravity': '0.85 standard',
#    'terrain': 'forests, mountains, lakes',
#    'surface_water': '8',
#    'population': '30000000',
#    'residents': ['https://swapi.co/api/people/30/'],
#    'films': ['https://swapi.co/api/films/3/'],
#    'created': '2014-12-10T11:50:29.349000Z',
#    'edited': '2014-12-20T20:58:18.429000Z',
#    'url': 'https://swapi.co/api/planets/7/'},
#   {'name': 'Naboo',
#    'rotation_period': '26',
#    'orbital_period': '312',
#    'diameter': '12120',
#    'climate': 'temperate',
#    'gravity': '1 standard',
#    'terrain': 'grassy hills, swamps, forests, mountains',
#    'surface_water': '12',
#    'population': '4500000000',
#    'residents': ['https://swapi.co/api/people/3/',
#     'https://swapi.co/api/people/21/',
#     'https://swapi.co/api/people/36/',
#     'https://swapi.co/api/people/37/',
#     'https://swapi.co/api/people/38/',
#     'https://swapi.co/api/people/39/',
#     'https://swapi.co/api/people/42/',
#     'https://swapi.co/api/people/60/',
#     'https://swapi.co/api/people/61/',
#     'https://swapi.co/api/people/66/',
#     'https://swapi.co/api/people/35/'],
#    'films': ['https://swapi.co/api/films/5/',
#     'https://swapi.co/api/films/4/',
#     'https://swapi.co/api/films/6/',
#     'https://swapi.co/api/films/3/'],
#    'created': '2014-12-10T11:52:31.066000Z',
#    'edited': '2014-12-20T20:58:18.430000Z',
#    'url': 'https://swapi.co/api/planets/8/'},
#   {'name': 'Coruscant',
#    'rotation_period': '24',
#    'orbital_period': '368',
#    'diameter': '12240',
#    'climate': 'temperate',
#    'gravity': '1 standard',
#    'terrain': 'cityscape, mountains',
#    'surface_water': 'unknown',
#    'population': '1000000000000',
#    'residents': ['https://swapi.co/api/people/34/',
#     'https://swapi.co/api/people/55/',
#     'https://swapi.co/api/people/74/'],
#    'films': ['https://swapi.co/api/films/5/',
#     'https://swapi.co/api/films/4/',
#     'https://swapi.co/api/films/6/',
#     'https://swapi.co/api/films/3/'],
#    'created': '2014-12-10T11:54:13.921000Z',
#    'edited': '2014-12-20T20:58:18.432000Z',
#    'url': 'https://swapi.co/api/planets/9/'},
#   {'name': 'Kamino',
#    'rotation_period': '27',
#    'orbital_period': '463',
#    'diameter': '19720',
#    'climate': 'temperate',
#    'gravity': '1 standard',
#    'terrain': 'ocean',
#    'surface_water': '100',
#    'population': '1000000000',
#    'residents': ['https://swapi.co/api/people/22/',
#     'https://swapi.co/api/people/72/',
#     'https://swapi.co/api/people/73/'],
#    'films': ['https://swapi.co/api/films/5/'],
#    'created': '2014-12-10T12:45:06.577000Z',
#    'edited': '2014-12-20T20:58:18.434000Z',
#    'url': 'https://swapi.co/api/planets/10/'},
#   {'name': 'Geonosis',
#    'rotation_period': '30',
#    'orbital_period': '256',
#    'diameter': '11370',
#    'climate': 'temperate, arid',
#    'gravity': '0.9 standard',
#    'terrain': 'rock, desert, mountain, barren',
#    'surface_water': '5',
#    'population': '100000000000',
#    'residents': ['https://swapi.co/api/people/63/'],
#    'films': ['https://swapi.co/api/films/5/'],
#    'created': '2014-12-10T12:47:22.350000Z',
#    'edited': '2014-12-20T20:58:18.437000Z',
#    'url': 'https://swapi.co/api/planets/11/'}]}

# %%
for entry in r.json()['results']:
    if 'temperate' in entry['climate']:
        print(entry['name'])
    else:
        print(entry['name'] + ' does not have a temperate climate.' )
# Out:
# Alderaan
# Yavin IV does not have a temperate climate.
# Hoth does not have a temperate climate.
# Dagobah does not have a temperate climate.
# Bespin
# Endor
# Naboo
# Coruscant
# Kamino
# Geonosis does not have a temperate climate.

# %%
for entry in r.json()['results']:
     try:
        if int(entry['population']) >= 1000:
            print(entry['name'] + ' has a population greater than or equal to 1000')
        else:
            print(entry['name'] + ' has a population less than 1000.')
     except ValueError:
         print (entry['name'] + ' has an unknown population')
# Out:
# Alderaan has a population greater than or equal to 1000
# Yavin IV has a population greater than or equal to 1000
# Hoth has an unknown population
# Dagobah has an unknown population
# Bespin has a population greater than or equal to 1000
# Endor has a population greater than or equal to 1000
# Naboo has a population greater than or equal to 1000
# Coruscant has a population greater than or equal to 1000
# Kamino has a population greater than or equal to 1000
# Geonosis has a population greater than or equal to 1000

# %%
cwd
# Out:
# 'C:\\Users\\estyw\\Desktop\\Python Instruction\\python-instruction-master'
