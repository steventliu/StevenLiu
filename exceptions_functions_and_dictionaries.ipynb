# %% [markdown]
# # Lesson Goals:
#
# - Understand exception handling syntax and techniques
# - Understand functions and the difference between recursive and iterative use
# - Understand complex dictionary use
# - Understand techniques for formatting output for user presentation

# %% [markdown]
# # Exception handling
# Exception handling is important in real world use of any programming language. Not all actions will succeed 100% of the time. That could be perfectly OK depending on your intended use. Let's explore this technique with an example.

# %%
import os     # used for various file/directory operations
import pprint # used for cleaner dictionary printing

try:
    from termcolor import colored # termcolor module used for fancy printing to user
except ModuleNotFoundError:
    # !pip install termcolor
    from termcolor import colored
# Out:
# Collecting termcolor
#   Using cached https://files.pythonhosted.org/packages/8a/48/a76be51647d0eb9f10e2a4511bf3ffb8cc1e6b14e9e4fab46173aa79f981/termcolor-1.1.0.tar.gz
# Building wheels for collected packages: termcolor
#   Running setup.py bdist_wheel for termcolor: started
#   Running setup.py bdist_wheel for termcolor: finished with status 'done'
#   Stored in directory: C:\Users\estyw\AppData\Local\pip\Cache\wheels\7c\06\54\bc84598ba1daf8f970247f550b175aaaee85f68b4b0c5ab2c6
# Successfully built termcolor
# Installing collected packages: termcolor
# Successfully installed termcolor-1.1.0

# %% [markdown]
# ### Warning
# The above is an anti-pattern not for real world use in your code. It's bad practice to assume on behalf of the users of your code that they want additional packages installed and this could be security vulnerability if ever actively targeted. Additionally, you won't always know if you have permissions to install packages depending on if code is run using the system Python or in a virtual environment.
#
# Additional reading: https://docs.python.org/3/tutorial/errors.html

# %%
'''
What termcolor gives us is easy use of ANSI escape sequences for color coding our output.
'''
print(colored('hello', 'red'), colored('world', 'green'))
# Out:
# hello world

# %% [markdown]
# # Functions
#
# ##### Recursive Functions
# It's been said that to understand recursion you must understand recursion. In programming terms, a recursion function is one where the function will call itself inside of it's function definition. Its value in practice depends on the programming language and use case. It can result in a very compact piece of code or it can result in infinite loop that never terminates if not used carefully.
#
# The example below uses a recursive function so that I can pass a reference a directory path that may be several folders deep in the dictionary mapping of file and folder names.
#
# #### Iterative Functions
# Iteration is a repeated action through a set of data until completed or a condition is reached. Python is very good at iteration and you are familiar with iterative actions such as `for` and `while` loops on data.

# %%
'''
Populate a dictionary given a path and an empty dictionary.

This uses the os.scandir which provides additional metadata about
items in the path than os.listdir. The result is an DirEntry object
with items we can enumerate and act upon.

https://docs.python.org/3/library/os.html#os.scandir
https://docs.python.org/3/library/os.html#os.DirEntry
'''

def recursive_directory_tree(path, structure):

    try:
        with os.scandir(path) as it:
            for entry in it:

                # Add files that are not hidden files (starting with . on Linux/Mac)
                if not entry.name.startswith('.') and entry.is_file():
                    print(colored("[+] Found file, updating value None for key:", 'green'),
                          colored(entry.name, 'blue'))
                    structure.update({entry.name: None})

                # Add directories that are not hidden and not shortcuts/symlinks
                elif not entry.name.startswith('.') and entry.is_dir() and not entry.is_symlink():
                    print(colored("[+] Found directory, updating value {} for key:", 'green'),
                          colored(entry.name, 'blue'))
                    structure.update({entry.name: {}})

                    print(colored("[*] Performing recursive function call on:", 'green'),
                          colored(entry.path, 'blue'))
                    recursive_directory_tree(entry.path, structure[entry.name])

    # Print colored warning when there is no permissions to directory
    except PermissionError:
        print(colored("[!] Skipping due to PermissionError for path:", 'red'),
            colored(path, 'red', attrs=['bold']))
    
    # Skip "osError: [Errno 34] Result too large" issue, why? I don't know...
    except OSError as e:
        if e == 34:
            pass

# '''
# With the above defined, we can define a path to enumerate and provide
# an empty dictionary.

# You may enumerate /Users (on Mac) or your "C:\Users" (on Windows) however
# be prepared for it to take a bit longer to complete.
# '''
path = '.'
structure = {}
recursive_directory_tree(path, structure)
# Out:
# [+] Found file, updating value None for key: api_output.csv
# [+] Found file, updating value None for key: basic_database_tech.ipynb
# [+] Found file, updating value None for key: basic_web_beautifulsoup4.ipynb
# [+] Found file, updating value None for key: basic_web_plus_api_call_interactions.ipynb
# [+] Found file, updating value None for key: camels.jpg
# [+] Found file, updating value None for key: Classes.ipynb
# [+] Found file, updating value None for key: data_serialization.ipynb
# [+] Found file, updating value None for key: dedup_files.ipynb
# [+] Found directory, updating value {} for key: duplicated
# [*] Performing recursive function call on: .\duplicated
# [+] Found file, updating value None for key: bptgxdeeipxu.txt
# [+] Found file, updating value None for key: fjiwtpgtgcdb.txt
# [+] Found file, updating value None for key: ibdlnqtlvaim.txt
# [+] Found file, updating value None for key: icspsjlksrbn.txt
# [+] Found file, updating value None for key: ioipomykrfom.txt
# [+] Found file, updating value None for key: jjiihzujdnki.txt
# [+] Found file, updating value None for key: jnvkounpkeit.txt
# [+] Found file, updating value None for key: lixeoutjwbtq.txt
# [+] Found file, updating value None for key: ljmndgqywrsi.txt
# [+] Found file, updating value None for key: lksequmqneep.txt
# [+] Found file, updating value None for key: nexygkahtozc.txt
# [+] Found file, updating value None for key: nhjxkxizisju.txt
# [+] Found file, updating value None for key: nlptvthvukcc.txt
# [+] Found file, updating value None for key: ocdwilpcpyme.txt
# [+] Found file, updating value None for key: odzmgnfcelwt.txt
# [+] Found file, updating value None for key: ogtwqijwefst.txt
# [+] Found file, updating value None for key: ovcsvnhebmxw.txt
# [+] Found file, updating value None for key: pdqzkppwvtbg.txt
# [+] Found file, updating value None for key: pedjujehkslo.txt
# [+] Found file, updating value None for key: qcdjkdlivhdl.txt
# [+] Found file, updating value None for key: qqrtcsambixf.txt
# [+] Found file, updating value None for key: rgnxruhulrqj.txt
# [+] Found file, updating value None for key: rsxuxfpjcpjg.txt
# [+] Found file, updating value None for key: rvavktnfzdhr.txt
# [+] Found file, updating value None for key: sfhxhyvdufzy.txt
# [+] Found file, updating value None for key: snqnqfljwwyi.txt
# [+] Found file, updating value None for key: tfceklaffttv.txt
# [+] Found file, updating value None for key: tnyyedaupagf.txt
# [+] Found file, updating value None for key: wexmbvsmavlo.txt
# [+] Found file, updating value None for key: xksdojojgywa.txt
# [+] Found file, updating value None for key: xpqwrdqcodwb.txt
# [+] Found file, updating value None for key: xqagxkswzyuu.txt
# [+] Found file, updating value None for key: xwbozdzaqmbm.txt
# [+] Found file, updating value None for key: ydutrxodquup.txt
# [+] Found file, updating value None for key: yvmexqkrvceb.txt
# [+] Found file, updating value None for key: zblwvaddjjpv.txt
# [+] Found file, updating value None for key: exceptions_functions_and_dictionaries.ipynb
# [+] Found directory, updating value {} for key: exif-samples-master
# [*] Performing recursive function call on: .\exif-samples-master
# [+] Found directory, updating value {} for key: jpg
# [*] Performing recursive function call on: .\exif-samples-master\jpg
# [+] Found file, updating value None for key: Canon_40D.jpg
# [+] Found file, updating value None for key: Canon_40D_photoshop_import.jpg
# [+] Found file, updating value None for key: Canon_DIGITAL_IXUS_400.jpg
# [+] Found file, updating value None for key: Canon_PowerShot_S40.jpg
# [+] Found file, updating value None for key: corrupted.jpg
# [+] Found directory, updating value {} for key: exif-org
# [*] Performing recursive function call on: .\exif-samples-master\jpg\exif-org
# [+] Found file, updating value None for key: canon-ixus.jpg
# [+] Found file, updating value None for key: fujifilm-dx10.jpg
# [+] Found file, updating value None for key: fujifilm-finepix40i.jpg
# [+] Found file, updating value None for key: fujifilm-mx1700.jpg
# [+] Found file, updating value None for key: kodak-dc210.jpg
# [+] Found file, updating value None for key: kodak-dc240.jpg
# [+] Found file, updating value None for key: nikon-e950.jpg
# [+] Found file, updating value None for key: olympus-c960.jpg
# [+] Found file, updating value None for key: olympus-d320l.jpg
# [+] Found file, updating value None for key: README
# [+] Found file, updating value None for key: ricoh-rdc5300.jpg
# [+] Found file, updating value None for key: sanyo-vpcg250.jpg
# [+] Found file, updating value None for key: sanyo-vpcsx550.jpg
# [+] Found file, updating value None for key: sony-cybershot.jpg
# [+] Found file, updating value None for key: sony-d700.jpg
# [+] Found file, updating value None for key: sony-powershota5.jpg
# [+] Found file, updating value None for key: Fujifilm_FinePix6900ZOOM.jpg
# [+] Found file, updating value None for key: Fujifilm_FinePix_E500.jpg
# [+] Found directory, updating value {} for key: gps
# [*] Performing recursive function call on: .\exif-samples-master\jpg\gps
# [+] Found file, updating value None for key: DSCN0010.jpg
# [+] Found file, updating value None for key: DSCN0012.jpg
# [+] Found file, updating value None for key: DSCN0021.jpg
# [+] Found file, updating value None for key: DSCN0025.jpg
# [+] Found file, updating value None for key: DSCN0027.jpg
# [+] Found file, updating value None for key: DSCN0029.jpg
# [+] Found file, updating value None for key: DSCN0038.jpg
# [+] Found file, updating value None for key: DSCN0040.jpg
# [+] Found file, updating value None for key: DSCN0042.jpg
# [+] Found file, updating value None for key: README
# [+] Found directory, updating value {} for key: hdr
# [*] Performing recursive function call on: .\exif-samples-master\jpg\hdr
# [+] Found file, updating value None for key: canon_hdr_NO.jpg
# [+] Found file, updating value None for key: canon_hdr_YES.jpg
# [+] Found file, updating value None for key: iphone_hdr_NO.jpg
# [+] Found file, updating value None for key: iphone_hdr_YES.jpg
# [+] Found file, updating value None for key: README
# [+] Found directory, updating value {} for key: invalid
# [*] Performing recursive function call on: .\exif-samples-master\jpg\invalid
# [+] Found file, updating value None for key: image00971.jpg
# [+] Found file, updating value None for key: image01088.jpg
# [+] Found file, updating value None for key: image01137.jpg
# [+] Found file, updating value None for key: image01551.jpg
# [+] Found file, updating value None for key: image01713.jpg
# [+] Found file, updating value None for key: image01980.jpg
# [+] Found file, updating value None for key: image02206.jpg
# [+] Found file, updating value None for key: README
# [+] Found file, updating value None for key: Kodak_CX7530.jpg
# [+] Found file, updating value None for key: Konica_Minolta_DiMAGE_Z3.jpg
# [+] Found file, updating value None for key: long_description.jpg
# [+] Found directory, updating value {} for key: mobile
# [*] Performing recursive function call on: .\exif-samples-master\jpg\mobile
# [+] Found file, updating value None for key: jolla.jpg
# [+] Found file, updating value None for key: Nikon_COOLPIX_P1.jpg
# [+] Found file, updating value None for key: Nikon_D70.jpg
# [+] Found file, updating value None for key: Olympus_C8080WZ.jpg
# [+] Found directory, updating value {} for key: orientation
# [*] Performing recursive function call on: .\exif-samples-master\jpg\orientation
# [+] Found file, updating value None for key: landscape_1.jpg
# [+] Found file, updating value None for key: landscape_2.jpg
# [+] Found file, updating value None for key: landscape_3.jpg
# [+] Found file, updating value None for key: landscape_4.jpg
# [+] Found file, updating value None for key: landscape_5.jpg
# [+] Found file, updating value None for key: landscape_6.jpg
# [+] Found file, updating value None for key: landscape_7.jpg
# [+] Found file, updating value None for key: landscape_8.jpg
# [+] Found file, updating value None for key: portrait_1.jpg
# [+] Found file, updating value None for key: portrait_2.jpg
# [+] Found file, updating value None for key: portrait_3.jpg
# [+] Found file, updating value None for key: portrait_4.jpg
# [+] Found file, updating value None for key: portrait_5.jpg
# [+] Found file, updating value None for key: portrait_6.jpg
# [+] Found file, updating value None for key: portrait_7.jpg
# [+] Found file, updating value None for key: portrait_8.jpg
# [+] Found file, updating value None for key: README
# [+] Found file, updating value None for key: PaintTool_sample.jpg
# [+] Found file, updating value None for key: Panasonic_DMC-FZ30.jpg
# [+] Found file, updating value None for key: Pentax_K10D.jpg
# [+] Found file, updating value None for key: README
# [+] Found file, updating value None for key: Ricoh_Caplio_RR330.jpg
# [+] Found file, updating value None for key: Samsung_Digimax_i50_MP3.jpg
# [+] Found file, updating value None for key: Sony_HDR-HC3.jpg
# [+] Found directory, updating value {} for key: tests
# [*] Performing recursive function call on: .\exif-samples-master\jpg\tests
# [+] Found file, updating value None for key: 11-tests.jpg
# [+] Found file, updating value None for key: 22-canon_tags.jpg
# [+] Found file, updating value None for key: 28-hex_value.jpg
# [+] Found file, updating value None for key: 30-type_error.jpg
# [+] Found file, updating value None for key: 32-lens_data.jpeg
# [+] Found file, updating value None for key: 33-type_error.jpg
# [+] Found file, updating value None for key: 35-empty.jpg
# [+] Found file, updating value None for key: 36-memory_error.jpg
# [+] Found file, updating value None for key: 42_IndexError.jpg
# [+] Found file, updating value None for key: 45-gps_ifd.jpg
# [+] Found file, updating value None for key: 46_UnicodeEncodeError.jpg
# [+] Found file, updating value None for key: 67-0_length_string.jpg
# [+] Found file, updating value None for key: WWL_(Polaroid)_ION230.jpg
# [+] Found directory, updating value {} for key: xmp
# [*] Performing recursive function call on: .\exif-samples-master\jpg\xmp
# [+] Found file, updating value None for key: BlueSquare.jpg
# [+] Found file, updating value None for key: no_exif.jpg
# [+] Found directory, updating value {} for key: petra
# [*] Performing recursive function call on: .\exif-samples-master\petra
# [+] Found file, updating value None for key: camels.jpg
# [+] Found file, updating value None for key: steven_camel.jpg
# [+] Found file, updating value None for key: README.rst
# [+] Found directory, updating value {} for key: tiff
# [*] Performing recursive function call on: .\exif-samples-master\tiff
# [+] Found file, updating value None for key: Arbitro.tiff
# [+] Found file, updating value None for key: BSG1.tiff
# [+] Found file, updating value None for key: Crémieux11.tiff
# [+] Found file, updating value None for key: DudleyLeavittUtah.tiff
# [+] Found file, updating value None for key: Jobagent.tiff
# [+] Found file, updating value None for key: Picoawards.tiff
# [+] Found file, updating value None for key: README
# [+] Found file, updating value None for key: Rudless.tiff
# [+] Found file, updating value None for key: Tless0.tiff
# [+] Found file, updating value None for key: exifdata.kml
# [+] Found file, updating value None for key: exifread_extracting_data.ipynb
# [+] Found file, updating value None for key: exifread_lesson.ipynb
# [+] Found file, updating value None for key: exifread_lesson_Jason_data.ipynb
# [+] Found file, updating value None for key: food.pickle
# [+] Found file, updating value None for key: food.shelve.bak
# [+] Found file, updating value None for key: food.shelve.dat
# [+] Found file, updating value None for key: food.shelve.dir
# [+] Found file, updating value None for key: Learning_Python3.ipynb
# [+] Found directory, updating value {} for key: machine-learning-project-walkthrough-master
# [*] Performing recursive function call on: .\machine-learning-project-walkthrough-master
# [+] Found file, updating value None for key: 2016_nyc_benchmarking_data_disclosure_definitions.pdf
# [+] Found directory, updating value {} for key: auto_ml
# [*] Performing recursive function call on: .\machine-learning-project-walkthrough-master\auto_ml
# [+] Found file, updating value None for key: tpot_exported_pipeline.py
# [+] Found file, updating value None for key: Building Data Report.pdf
# [+] Found directory, updating value {} for key: data
# [*] Performing recursive function call on: .\machine-learning-project-walkthrough-master\data
# [+] Found file, updating value None for key: cleaned_data.csv
# [+] Found file, updating value None for key: Energy_and_Water_Data_Disclosure_for_Local_Law_84_2017__Data_for_Calendar_Year_2016_.csv
# [+] Found file, updating value None for key: no_score.csv
# [+] Found file, updating value None for key: testing_features.csv
# [+] Found file, updating value None for key: testing_labels.csv
# [+] Found file, updating value None for key: training_features.csv
# [+] Found file, updating value None for key: training_labels.csv
# [+] Found file, updating value None for key: X_test.csv
# [+] Found file, updating value None for key: X_train.csv
# [+] Found file, updating value None for key: Y_test.csv
# [+] Found file, updating value None for key: Y_train.csv
# [+] Found directory, updating value {} for key: deprecated
# [*] Performing recursive function call on: .\machine-learning-project-walkthrough-master\deprecated
# [+] Found file, updating value None for key: Building Data Report.ipynb
# [+] Found file, updating value None for key: Exploratory_Work.ipynb
# [+] Found file, updating value None for key: hw_assignment.docx
# [+] Found file, updating value None for key: hw_assignment.pdf
# [+] Found directory, updating value {} for key: images
# [*] Performing recursive function call on: .\machine-learning-project-walkthrough-master\images
# [+] Found file, updating value None for key: annotated_individual_node.PNG
# [+] Found file, updating value None for key: correlation_examples.png
# [+] Found file, updating value None for key: cover_auto_ml.jpg
# [+] Found file, updating value None for key: cover_one.jpg
# [+] Found file, updating value None for key: cover_three.jpg
# [+] Found file, updating value None for key: cover_two.jpg
# [+] Found file, updating value None for key: data_formatted_with_score.PNG
# [+] Found file, updating value None for key: density_boroughs.png
# [+] Found file, updating value None for key: density_type.png
# [+] Found file, updating value None for key: df_info.PNG
# [+] Found file, updating value None for key: feature_importances.PNG
# [+] Found file, updating value None for key: feature_importances_graph.png
# [+] Found file, updating value None for key: feature_pairs.png
# [+] Found file, updating value None for key: formatted_train_data.PNG
# [+] Found file, updating value None for key: individual_node.png
# [+] Found file, updating value None for key: intrepretability_vs_accuracy.png
# [+] Found file, updating value None for key: kfold_cv.png
# [+] Found file, updating value None for key: lime_wrong_explanation.PNG
# [+] Found file, updating value None for key: local_explanation_one.png
# [+] Found file, updating value None for key: missing_values.PNG
# [+] Found file, updating value None for key: model_comparison.png
# [+] Found file, updating value None for key: negative_correlations.PNG
# [+] Found file, updating value None for key: nestimator_performance.png
# [+] Found file, updating value None for key: positive_correlations.PNG
# [+] Found file, updating value None for key: raw_data.PNG
# [+] Found file, updating value None for key: residual_distribution.png
# [+] Found file, updating value None for key: score_distribution.png
# [+] Found file, updating value None for key: score_vs_eui.png
# [+] Found file, updating value None for key: test_prediction_density.png
# [+] Found file, updating value None for key: test_values.png
# [+] Found file, updating value None for key: tpot-ml-pipeline.png
# [+] Found file, updating value None for key: tpot_training_information.PNG
# [+] Found file, updating value None for key: tree.dot
# [+] Found file, updating value None for key: tree.png
# [+] Found file, updating value None for key: tree_single.dot
# [+] Found file, updating value None for key: tree_single.png
# [+] Found file, updating value None for key: tree_single_small.dot
# [+] Found file, updating value None for key: tree_single_small.png
# [+] Found file, updating value None for key: tree_small.dot
# [+] Found file, updating value None for key: tree_small.png
# [+] Found file, updating value None for key: tree_verysmall.dot
# [+] Found file, updating value None for key: tree_verysmall.png
# [+] Found file, updating value None for key: weather_norm_eui.png
# [+] Found file, updating value None for key: wrong_explanation_plot.png
# [+] Found file, updating value None for key: Machine Learning Project Part 1.ipynb
# [+] Found file, updating value None for key: Machine Learning Project Part 2.ipynb
# [+] Found file, updating value None for key: Machine Learning Project Part 3.ipynb
# [+] Found file, updating value None for key: README.md
# [+] Found file, updating value None for key: MatPlotLib.ipynb
# [+] Found directory, updating value {} for key: matplotlibstuff
# [*] Performing recursive function call on: .\matplotlibstuff
# [+] Found directory, updating value {} for key: basemap-1.1.0
# [*] Performing recursive function call on: .\matplotlibstuff\basemap-1.1.0
# [+] Found file, updating value None for key: API_CHANGES
# [+] Found file, updating value None for key: Changelog
# [+] Found directory, updating value {} for key: doc
# [*] Performing recursive function call on: .\matplotlibstuff\basemap-1.1.0\doc
# [+] Found directory, updating value {} for key: api
# [*] Performing recursive function call on: .\matplotlibstuff\basemap-1.1.0\doc\api
# [+] Found file, updating value None for key: basemap_api.rst
# [+] Found file, updating value None for key: index.rst
# [+] Found file, updating value None for key: conf.py
# [+] Found file, updating value None for key: index.rst
# [+] Found file, updating value None for key: make.py
# [+] Found file, updating value None for key: matplotlibrc
# [+] Found file, updating value None for key: README.txt
# [+] Found directory, updating value {} for key: users
# [*] Performing recursive function call on: .\matplotlibstuff\basemap-1.1.0\doc\users
# [+] Found file, updating value None for key: aea.rst
# [+] Found file, updating value None for key: aeqd.rst
# [+] Found file, updating value None for key: cass.rst
# [+] Found file, updating value None for key: cea.rst
# [+] Found file, updating value None for key: cyl.rst
# [+] Found file, updating value None for key: download.rst
# [+] Found file, updating value None for key: eck4.rst
# [+] Found file, updating value None for key: eqdc.rst
# [+] Found file, updating value None for key: examples.rst
# [+] Found directory, updating value {} for key: figures
# [*] Performing recursive function call on: .\matplotlibstuff\basemap-1.1.0\doc\users\figures
# [+] Found file, updating value None for key: aea.py
# [+] Found file, updating value None for key: aeqd.py
# [+] Found file, updating value None for key: aeqd_fulldisk.py
# [+] Found file, updating value None for key: azeqd.py
# [+] Found file, updating value None for key: background1.py
# [+] Found file, updating value None for key: background2.py
# [+] Found file, updating value None for key: background3.py
# [+] Found file, updating value None for key: background4.py
# [+] Found file, updating value None for key: background5.py
# [+] Found file, updating value None for key: cass.py
# [+] Found file, updating value None for key: cea.py
# [+] Found file, updating value None for key: contour1.py
# [+] Found file, updating value None for key: cyl.py
# [+] Found file, updating value None for key: eck4.py
# [+] Found file, updating value None for key: eqdc.py
# [+] Found file, updating value None for key: gall.py
# [+] Found file, updating value None for key: geos_full.py
# [+] Found file, updating value None for key: geos_partial.py
# [+] Found file, updating value None for key: gnomon.py
# [+] Found file, updating value None for key: graticule.py
# [+] Found file, updating value None for key: hammer.py
# [+] Found file, updating value None for key: hurrtracks.py
# [+] Found file, updating value None for key: kav7.py
# [+] Found file, updating value None for key: laea.py
# [+] Found file, updating value None for key: lcc.py
# [+] Found file, updating value None for key: mbtfpq.py
# [+] Found file, updating value None for key: merc.py
# [+] Found file, updating value None for key: mill.py
# [+] Found file, updating value None for key: moll.py
# [+] Found file, updating value None for key: npaeqd.py
# [+] Found file, updating value None for key: nplaea.py
# [+] Found file, updating value None for key: npstere.py
# [+] Found file, updating value None for key: nsper_full.py
# [+] Found file, updating value None for key: nsper_partial.py
# [+] Found file, updating value None for key: omerc.py
# [+] Found file, updating value None for key: ortho_full.py
# [+] Found file, updating value None for key: ortho_partial.py
# [+] Found file, updating value None for key: plotargo.py
# [+] Found file, updating value None for key: plotboulder.py
# [+] Found file, updating value None for key: plotdaynight.py
# [+] Found file, updating value None for key: plotetopo5.py
# [+] Found file, updating value None for key: plotgreatcircle.py
# [+] Found file, updating value None for key: plothighsandlows.py
# [+] Found file, updating value None for key: plotprecip.py
# [+] Found file, updating value None for key: plotsst.py
# [+] Found file, updating value None for key: plotwindvec.py
# [+] Found file, updating value None for key: poly.py
# [+] Found file, updating value None for key: robin.py
# [+] Found file, updating value None for key: sinu.py
# [+] Found file, updating value None for key: spaeqd.py
# [+] Found file, updating value None for key: splaea.py
# [+] Found file, updating value None for key: spstere.py
# [+] Found file, updating value None for key: stere.py
# [+] Found file, updating value None for key: tmerc.py
# [+] Found file, updating value None for key: vandg.py
# [+] Found file, updating value None for key: gall.rst
# [+] Found file, updating value None for key: geography.rst
# [+] Found file, updating value None for key: geos.rst
# [+] Found file, updating value None for key: gnomon.rst
# [+] Found file, updating value None for key: graticule.rst
# [+] Found file, updating value None for key: hammer.rst
# [+] Found file, updating value None for key: index.rst
# [+] Found file, updating value None for key: installing.rst
# [+] Found file, updating value None for key: intro.rst
# [+] Found file, updating value None for key: kav7.rst
# [+] Found file, updating value None for key: laea.rst
# [+] Found file, updating value None for key: lcc.rst
# [+] Found file, updating value None for key: mapcoords.rst
# [+] Found file, updating value None for key: mapsetup.rst
# [+] Found file, updating value None for key: mbtfpq.rst
# [+] Found file, updating value None for key: merc.rst
# [+] Found file, updating value None for key: mill.rst
# [+] Found file, updating value None for key: moll.rst
# [+] Found file, updating value None for key: nsper.rst
# [+] Found file, updating value None for key: omerc.rst
# [+] Found file, updating value None for key: ortho.rst
# [+] Found file, updating value None for key: paeqd.rst
# [+] Found file, updating value None for key: plaea.rst
# [+] Found file, updating value None for key: poly.rst
# [+] Found file, updating value None for key: pstere.rst
# [+] Found file, updating value None for key: robin.rst
# [+] Found file, updating value None for key: sinu.rst
# [+] Found file, updating value None for key: stere.rst
# [+] Found file, updating value None for key: tmerc.rst
# [+] Found file, updating value None for key: vandg.rst
# [+] Found directory, updating value {} for key: examples
# [*] Performing recursive function call on: .\matplotlibstuff\basemap-1.1.0\examples
# [+] Found file, updating value None for key: 200706041200-msg-ch01-SAfrica.jpg
# [+] Found file, updating value None for key: 500hgtdata.gz
# [+] Found file, updating value None for key: 500hgtlats.gz
# [+] Found file, updating value None for key: 500hgtlons.gz
# [+] Found file, updating value None for key: allskymap.py
# [+] Found file, updating value None for key: allskymap_cr_example.py
# [+] Found file, updating value None for key: animate.py
# [+] Found file, updating value None for key: barb_demo.py
# [+] Found file, updating value None for key: C02562.orog.nc
# [+] Found file, updating value None for key: camx.sample.nc
# [+] Found file, updating value None for key: ccsm_popgrid.nc
# [+] Found file, updating value None for key: ccsm_popgrid.py
# [+] Found file, updating value None for key: cities.dbf
# [+] Found file, updating value None for key: cities.shp
# [+] Found file, updating value None for key: cities.shx
# [+] Found file, updating value None for key: contour_demo.py
# [+] Found file, updating value None for key: counties.py
# [+] Found file, updating value None for key: cubed_sphere.py
# [+] Found file, updating value None for key: customticks.py
# [+] Found file, updating value None for key: daynight.py
# [+] Found file, updating value None for key: earth_lights_lrg.jpg
# [+] Found file, updating value None for key: embedding_map_in_wx.py
# [+] Found file, updating value None for key: etopo20data.gz
# [+] Found file, updating value None for key: etopo20lats.gz
# [+] Found file, updating value None for key: etopo20lons.gz
# [+] Found file, updating value None for key: fcover.dat
# [+] Found file, updating value None for key: fcstmaps.py
# [+] Found file, updating value None for key: fcstmaps_axesgrid.py
# [+] Found file, updating value None for key: fillstates.py
# [+] Found file, updating value None for key: garp.py
# [+] Found file, updating value None for key: geos_demo.py
# [+] Found file, updating value None for key: geos_demo_2.py
# [+] Found file, updating value None for key: geos_demo_3.py
# [+] Found file, updating value None for key: hexbin_demo.py
# [+] Found file, updating value None for key: hires.py
# [+] Found file, updating value None for key: huralll020.dbf
# [+] Found file, updating value None for key: huralll020.shp
# [+] Found file, updating value None for key: huralll020.shx
# [+] Found file, updating value None for key: hurrtracks.py
# [+] Found file, updating value None for key: land_shallow_topo_2048.jpg
# [+] Found file, updating value None for key: lic_demo.py
# [+] Found file, updating value None for key: make_inset.py
# [+] Found file, updating value None for key: maskoceans.py
# [+] Found file, updating value None for key: nsper_demo.py
# [+] Found file, updating value None for key: nws_precip_conus_20061222.nc
# [+] Found file, updating value None for key: nytolondon.py
# [+] Found file, updating value None for key: ortho_demo.py
# [+] Found file, updating value None for key: panelplot.py
# [+] Found file, updating value None for key: plotcities.py
# [+] Found file, updating value None for key: plothighsandlows.py
# [+] Found file, updating value None for key: ploticos.py
# [+] Found file, updating value None for key: plotmap.py
# [+] Found file, updating value None for key: plotmap_masked.py
# [+] Found file, updating value None for key: plotmap_oo.py
# [+] Found file, updating value None for key: plotmap_shaded.py
# [+] Found file, updating value None for key: plotozone.py
# [+] Found file, updating value None for key: plotprecip.py
# [+] Found file, updating value None for key: plotsst.py
# [+] Found file, updating value None for key: plot_tissot.py
# [+] Found file, updating value None for key: polarmaps.py
# [+] Found file, updating value None for key: quiver_demo.py
# [+] Found file, updating value None for key: randompoints.py
# [+] Found file, updating value None for key: README
# [+] Found file, updating value None for key: rita.nc
# [+] Found file, updating value None for key: run_all.py
# [+] Found file, updating value None for key: save_background.py
# [+] Found file, updating value None for key: setwh.py
# [+] Found file, updating value None for key: shiftdata.py
# [+] Found file, updating value None for key: show_colormaps.py
# [+] Found file, updating value None for key: simpletest.py
# [+] Found file, updating value None for key: simpletest_oo.py
# [+] Found file, updating value None for key: st99_d00.dbf
# [+] Found file, updating value None for key: st99_d00.shp
# [+] Found file, updating value None for key: st99_d00.shx
# [+] Found file, updating value None for key: streamplot_demo.py
# [+] Found file, updating value None for key: test.py
# [+] Found file, updating value None for key: testarcgis.py
# [+] Found file, updating value None for key: testgdal.py
# [+] Found file, updating value None for key: testwmsimage.py
# [+] Found file, updating value None for key: test_rotpole.py
# [+] Found file, updating value None for key: us_25m.dem
# [+] Found file, updating value None for key: utmtest.py
# [+] Found file, updating value None for key: warpimage.py
# [+] Found file, updating value None for key: wiki_example.py
# [+] Found file, updating value None for key: wm201_Arctic_JJA_1990-2008_moyenneDesMoyennes.nc
# [+] Found file, updating value None for key: FAQ
# [+] Found directory, updating value {} for key: geos-3.3.3
# [*] Performing recursive function call on: .\matplotlibstuff\basemap-1.1.0\geos-3.3.3
# [+] Found file, updating value None for key: aclocal.m4
# [+] Found file, updating value None for key: acsite.m4
# [+] Found file, updating value None for key: AUTHORS
# [+] Found file, updating value None for key: autogen.bat
# [+] Found directory, updating value {} for key: capi
# [*] Performing recursive function call on: .\matplotlibstuff\basemap-1.1.0\geos-3.3.3\capi
# [+] Found file, updating value None for key: CMakeLists.txt
# [+] Found file, updating value None for key: geos_c.cpp
# [+] Found file, updating value None for key: geos_c.h
# [+] Found file, updating value None for key: geos_c.h.in
# [+] Found file, updating value None for key: geos_ts_c.cpp
# [+] Found file, updating value None for key: Makefile.am
# [+] Found file, updating value None for key: Makefile.in
# [+] Found file, updating value None for key: ChangeLog
# [+] Found directory, updating value {} for key: cmake
# [*] Performing recursive function call on: .\matplotlibstuff\basemap-1.1.0\geos-3.3.3\cmake
# [+] Found file, updating value None for key: cmake_uninstall.cmake.in
# [+] Found directory, updating value {} for key: modules
# [*] Performing recursive function call on: .\matplotlibstuff\basemap-1.1.0\geos-3.3.3\cmake\modules
# [+] Found file, updating value None for key: CheckPrototypeExists.cmake
# [+] Found file, updating value None for key: COPYING-CMAKE-SCRIPTS
# [+] Found file, updating value None for key: CMakeLists.txt
# [+] Found file, updating value None for key: config.guess
# [+] Found file, updating value None for key: config.sub
# [+] Found file, updating value None for key: configure
# [+] Found file, updating value None for key: configure.in
# [+] Found file, updating value None for key: COPYING
# [+] Found file, updating value None for key: depcomp
# [+] Found directory, updating value {} for key: doc
# [*] Performing recursive function call on: .\matplotlibstuff\basemap-1.1.0\geos-3.3.3\doc
# [+] Found file, updating value None for key: Doxyfile
# [+] Found file, updating value None for key: Doxyfile.in
# [+] Found file, updating value None for key: example.cpp
# [+] Found file, updating value None for key: Makefile.am
# [+] Found file, updating value None for key: Makefile.in
# [+] Found file, updating value None for key: README
# [+] Found directory, updating value {} for key: include
# [*] Performing recursive function call on: .\matplotlibstuff\basemap-1.1.0\geos-3.3.3\include
# [+] Found file, updating value None for key: CMakeLists.txt
# [+] Found file, updating value None for key: config.h.in
# [+] Found directory, updating value {} for key: geos
# [*] Performing recursive function call on: .\matplotlibstuff\basemap-1.1.0\geos-3.3.3\include\geos
# [+] Found directory, updating value {} for key: algorithm
# [*] Performing recursive function call on: .\matplotlibstuff\basemap-1.1.0\geos-3.3.3\include\geos\algorithm
# [+] Found file, updating value None for key: Angle.h
# [+] Found file, updating value None for key: BoundaryNodeRule.h
# [+] Found file, updating value None for key: CentralEndpointIntersector.h
# [+] Found file, updating value None for key: CentroidArea.h
# [+] Found file, updating value None for key: CentroidLine.h
# [+] Found file, updating value None for key: CentroidPoint.h
# [+] Found file, updating value None for key: CGAlgorithms.h
# [+] Found file, updating value None for key: ConvexHull.h
# [+] Found file, updating value None for key: ConvexHull.inl
# [+] Found directory, updating value {} for key: distance
# [*] Performing recursive function call on: .\matplotlibstuff\basemap-1.1.0\geos-3.3.3\include\geos\algorithm\distance
# [+] Found file, updating value None for key: DiscreteHausdorffDistance.h
# [+] Found file, updating value None for key: DistanceToPoint.h
# [+] Found file, updating value None for key: Makefile.am
# [+] Found file, updating value None for key: Makefile.in
# [+] Found file, updating value None for key: PointPairDistance.h
# [+] Found file, updating value None for key: HCoordinate.h
# [+] Found file, updating value None for key: InteriorPointArea.h
# [+] Found file, updating value None for key: InteriorPointLine.h
# [+] Found file, updating value None for key: InteriorPointPoint.h
# [+] Found file, updating value None for key: LineIntersector.h
# [+] Found directory, updating value {} for key: locate
# [*] Performing recursive function call on: .\matplotlibstuff\basemap-1.1.0\geos-3.3.3\include\geos\algorithm\locate
# [+] Found file, updating value None for key: IndexedPointInAreaLocator.h
# [+] Found file, updating value None for key: Makefile.am
# [+] Found file, updating value None for key: Makefile.in
# [+] Found file, updating value None for key: PointOnGeometryLocator.h
# [+] Found file, updating value None for key: SimplePointInAreaLocator.h
# [+] Found file, updating value None for key: Makefile.am
# [+] Found file, updating value None for key: Makefile.in
# [+] Found file, updating value None for key: MCPointInRing.h
# [+] Found file, updating value None for key: MinimumDiameter.h
# [+] Found file, updating value None for key: NotRepresentableException.h
# [+] Found file, updating value None for key: PointInRing.h
# [+] Found file, updating value None for key: PointLocator.h
# [+] Found file, updating value None for key: RayCrossingCounter.h
# [+] Found file, updating value None for key: RobustDeterminant.h
# [+] Found file, updating value None for key: SimplePointInRing.h
# [+] Found file, updating value None for key: SIRtreePointInRing.h
# [+] Found file, updating value None for key: export.h
# [+] Found directory, updating value {} for key: geom
# [*] Performing recursive function call on: .\matplotlibstuff\basemap-1.1.0\geos-3.3.3\include\geos\geom
# [+] Found file, updating value None for key: BinaryOp.h
# [+] Found file, updating value None for key: Coordinate.h
# [+] Found file, updating value None for key: Coordinate.inl
# [+] Found file, updating value None for key: CoordinateArraySequence.h
# [+] Found file, updating value None for key: CoordinateArraySequenceFactory.h
# [+] Found file, updating value None for key: CoordinateArraySequenceFactory.inl
# [+] Found file, updating value None for key: CoordinateFilter.h
# [+] Found file, updating value None for key: CoordinateList.h
# [+] Found file, updating value None for key: CoordinateSequence.h
# [+] Found file, updating value None for key: CoordinateSequenceFactory.h
# [+] Found file, updating value None for key: CoordinateSequenceFilter.h
# [+] Found file, updating value None for key: Dimension.h
# [+] Found file, updating value None for key: Envelope.h
# [+] Found file, updating value None for key: Envelope.inl
# [+] Found file, updating value None for key: Geometry.h
# [+] Found file, updating value None for key: GeometryCollection.h
# [+] Found file, updating value None for key: GeometryCollection.inl
# [+] Found file, updating value None for key: GeometryComponentFilter.h
# [+] Found file, updating value None for key: GeometryFactory.h
# [+] Found file, updating value None for key: GeometryFactory.inl
# [+] Found file, updating value None for key: GeometryFilter.h
# [+] Found file, updating value None for key: GeometryList.h
# [+] Found file, updating value None for key: IntersectionMatrix.h
# [+] Found file, updating value None for key: Lineal.h
# [+] Found file, updating value None for key: LinearRing.h
# [+] Found file, updating value None for key: LineSegment.h
# [+] Found file, updating value None for key: LineSegment.inl
# [+] Found file, updating value None for key: LineString.h
# [+] Found file, updating value None for key: Location.h
# [+] Found file, updating value None for key: Makefile.am
# [+] Found file, updating value None for key: Makefile.in
# [+] Found file, updating value None for key: MultiLineString.h
# [+] Found file, updating value None for key: MultiLineString.inl
# [+] Found file, updating value None for key: MultiPoint.h
# [+] Found file, updating value None for key: MultiPolygon.h
# [+] Found file, updating value None for key: MultiPolygon.inl
# [+] Found file, updating value None for key: Point.h
# [+] Found file, updating value None for key: Polygon.h
# [+] Found file, updating value None for key: Polygonal.h
# [+] Found file, updating value None for key: PrecisionModel.h
# [+] Found file, updating value None for key: PrecisionModel.inl
# [+] Found directory, updating value {} for key: prep
# [*] Performing recursive function call on: .\matplotlibstuff\basemap-1.1.0\geos-3.3.3\include\geos\geom\prep
# [+] Found file, updating value None for key: AbstractPreparedPolygonContains.h
# [+] Found file, updating value None for key: BasicPreparedGeometry.h
# [+] Found file, updating value None for key: Makefile.am
# [+] Found file, updating value None for key: Makefile.in
# [+] Found file, updating value None for key: PreparedGeometry.h
# [+] Found file, updating value None for key: PreparedGeometryFactory.h
# [+] Found file, updating value None for key: PreparedLineString.h
# [+] Found file, updating value None for key: PreparedLineStringIntersects.h
# [+] Found file, updating value None for key: PreparedPoint.h
# [+] Found file, updating value None for key: PreparedPolygon.h
# [+] Found file, updating value None for key: PreparedPolygonContains.h
# [+] Found file, updating value None for key: PreparedPolygonContainsProperly.h
# [+] Found file, updating value None for key: PreparedPolygonCovers.h
# [+] Found file, updating value None for key: PreparedPolygonIntersects.h
# [+] Found file, updating value None for key: PreparedPolygonPredicate.h
# [+] Found file, updating value None for key: Puntal.h
# [+] Found file, updating value None for key: Triangle.h
# [+] Found directory, updating value {} for key: util
# [*] Performing recursive function call on: .\matplotlibstuff\basemap-1.1.0\geos-3.3.3\include\geos\geom\util
# [+] Found file, updating value None for key: ComponentCoordinateExtracter.h
# [+] Found file, updating value None for key: CoordinateOperation.h
# [+] Found file, updating value None for key: GeometryCombiner.h
# [+] Found file, updating value None for key: GeometryEditor.h
# [+] Found file, updating value None for key: GeometryEditorOperation.h
# [+] Found file, updating value None for key: GeometryExtracter.h
# [+] Found file, updating value None for key: GeometryTransformer.h
# [+] Found file, updating value None for key: LinearComponentExtracter.h
# [+] Found file, updating value None for key: Makefile.am
# [+] Found file, updating value None for key: Makefile.in
# [+] Found file, updating value None for key: PointExtracter.h
# [+] Found file, updating value None for key: PolygonExtracter.h
# [+] Found file, updating value None for key: ShortCircuitedGeometryVisitor.h
# [+] Found file, updating value None for key: SineStarFactory.h
# [+] Found file, updating value None for key: geom.h
# [+] Found directory, updating value {} for key: geomgraph
# [*] Performing recursive function call on: .\matplotlibstuff\basemap-1.1.0\geos-3.3.3\include\geos\geomgraph
# [+] Found file, updating value None for key: Depth.h
# [+] Found file, updating value None for key: DirectedEdge.h
# [+] Found file, updating value None for key: DirectedEdge.inl
# [+] Found file, updating value None for key: DirectedEdgeStar.h
# [+] Found file, updating value None for key: Edge.h
# [+] Found file, updating value None for key: EdgeEnd.h
# [+] Found file, updating value None for key: EdgeEndStar.h
# [+] Found file, updating value None for key: EdgeIntersection.h
# [+] Found file, updating value None for key: EdgeIntersectionList.h
# [+] Found file, updating value None for key: EdgeList.h
# [+] Found file, updating value None for key: EdgeNodingValidator.h
# [+] Found file, updating value None for key: EdgeRing.h
# [+] Found file, updating value None for key: GeometryGraph.h
# [+] Found file, updating value None for key: GeometryGraph.inl
# [+] Found file, updating value None for key: GraphComponent.h
# [+] Found directory, updating value {} for key: index
# [*] Performing recursive function call on: .\matplotlibstuff\basemap-1.1.0\geos-3.3.3\include\geos\geomgraph\index
# [+] Found file, updating value None for key: EdgeSetIntersector.h
# [+] Found file, updating value None for key: Makefile.am
# [+] Found file, updating value None for key: Makefile.in
# [+] Found file, updating value None for key: MonotoneChain.h
# [+] Found file, updating value None for key: MonotoneChainEdge.h
# [+] Found file, updating value None for key: MonotoneChainIndexer.h
# [+] Found file, updating value None for key: SegmentIntersector.h
# [+] Found file, updating value None for key: SimpleEdgeSetIntersector.h
# [+] Found file, updating value None for key: SimpleMCSweepLineIntersector.h
# [+] Found file, updating value None for key: SimpleSweepLineIntersector.h
# [+] Found file, updating value None for key: SweepLineEvent.h
# [+] Found file, updating value None for key: SweepLineEventObj.h
# [+] Found file, updating value None for key: SweepLineSegment.h
# [+] Found file, updating value None for key: Label.h
# [+] Found file, updating value None for key: Makefile.am
# [+] Found file, updating value None for key: Makefile.in
# [+] Found file, updating value None for key: Node.h
# [+] Found file, updating value None for key: NodeFactory.h
# [+] Found file, updating value None for key: NodeMap.h
# [+] Found file, updating value None for key: PlanarGraph.h
# [+] Found file, updating value None for key: Position.h
# [+] Found file, updating value None for key: Quadrant.h
# [+] Found file, updating value None for key: TopologyLocation.h
# [+] Found file, updating value None for key: geomgraph.h
# [+] Found file, updating value None for key: geomgraphindex.h
# [+] Found file, updating value None for key: geomUtil.h
# [+] Found file, updating value None for key: geosAlgorithm.h
# [+] Found directory, updating value {} for key: index
# [*] Performing recursive function call on: .\matplotlibstuff\basemap-1.1.0\geos-3.3.3\include\geos\index
# [+] Found directory, updating value {} for key: bintree
# [*] Performing recursive function call on: .\matplotlibstuff\basemap-1.1.0\geos-3.3.3\include\geos\index\bintree
# [+] Found file, updating value None for key: Bintree.h
# [+] Found file, updating value None for key: Interval.h
# [+] Found file, updating value None for key: Key.h
# [+] Found file, updating value None for key: Makefile.am
# [+] Found file, updating value None for key: Makefile.in
# [+] Found file, updating value None for key: Node.h
# [+] Found file, updating value None for key: NodeBase.h
# [+] Found file, updating value None for key: Root.h
# [+] Found directory, updating value {} for key: chain
# [*] Performing recursive function call on: .\matplotlibstuff\basemap-1.1.0\geos-3.3.3\include\geos\index\chain
# [+] Found file, updating value None for key: Makefile.am
# [+] Found file, updating value None for key: Makefile.in
# [+] Found file, updating value None for key: MonotoneChain.h
# [+] Found file, updating value None for key: MonotoneChainBuilder.h
# [+] Found file, updating value None for key: MonotoneChainOverlapAction.h
# [+] Found file, updating value None for key: MonotoneChainSelectAction.h
# [+] Found directory, updating value {} for key: intervalrtree
# [*] Performing recursive function call on: .\matplotlibstuff\basemap-1.1.0\geos-3.3.3\include\geos\index\intervalrtree
# [+] Found file, updating value None for key: IntervalRTreeBranchNode.h
# [+] Found file, updating value None for key: IntervalRTreeLeafNode.h
# [+] Found file, updating value None for key: IntervalRTreeNode.h
# [+] Found file, updating value None for key: Makefile.am
# [+] Found file, updating value None for key: Makefile.in
# [+] Found file, updating value None for key: SortedPackedIntervalRTree.h
# [+] Found file, updating value None for key: ItemVisitor.h
# [+] Found file, updating value None for key: Makefile.am
# [+] Found file, updating value None for key: Makefile.in
# [+] Found directory, updating value {} for key: quadtree
# [*] Performing recursive function call on: .\matplotlibstuff\basemap-1.1.0\geos-3.3.3\include\geos\index\quadtree
# [+] Found file, updating value None for key: DoubleBits.h
# [+] Found file, updating value None for key: IntervalSize.h
# [+] Found file, updating value None for key: Key.h
# [+] Found file, updating value None for key: Makefile.am
# [+] Found file, updating value None for key: Makefile.in
# [+] Found file, updating value None for key: Node.h
# [+] Found file, updating value None for key: NodeBase.h
# [+] Found file, updating value None for key: Quadtree.h
# [+] Found file, updating value None for key: Root.h
# [+] Found file, updating value None for key: SpatialIndex.h
# [+] Found directory, updating value {} for key: strtree
# [*] Performing recursive function call on: .\matplotlibstuff\basemap-1.1.0\geos-3.3.3\include\geos\index\strtree
# [+] Found file, updating value None for key: AbstractNode.h
# [+] Found file, updating value None for key: AbstractSTRtree.h
# [+] Found file, updating value None for key: Boundable.h
# [+] Found file, updating value None for key: Interval.h
# [+] Found file, updating value None for key: ItemBoundable.h
# [+] Found file, updating value None for key: Makefile.am
# [+] Found file, updating value None for key: Makefile.in
# [+] Found file, updating value None for key: SIRtree.h
# [+] Found file, updating value None for key: STRtree.h
# [+] Found directory, updating value {} for key: sweepline
# [*] Performing recursive function call on: .\matplotlibstuff\basemap-1.1.0\geos-3.3.3\include\geos\index\sweepline
# [+] Found file, updating value None for key: Makefile.am
# [+] Found file, updating value None for key: Makefile.in
# [+] Found file, updating value None for key: SweepLineEvent.h
# [+] Found file, updating value None for key: SweepLineIndex.h
# [+] Found file, updating value None for key: SweepLineInterval.h
# [+] Found file, updating value None for key: SweepLineOverlapAction.h
# [+] Found file, updating value None for key: indexBintree.h
# [+] Found file, updating value None for key: indexChain.h
# [+] Found file, updating value None for key: indexQuadtree.h
# [+] Found file, updating value None for key: indexStrtree.h
# [+] Found file, updating value None for key: indexSweepline.h
# [+] Found file, updating value None for key: inline.h
# [+] Found directory, updating value {} for key: io
# [*] Performing recursive function call on: .\matplotlibstuff\basemap-1.1.0\geos-3.3.3\include\geos\io
# [+] Found file, updating value None for key: ByteOrderDataInStream.h
# [+] Found file, updating value None for key: ByteOrderDataInStream.inl
# [+] Found file, updating value None for key: ByteOrderValues.h
# [+] Found file, updating value None for key: CLocalizer.h
# [+] Found file, updating value None for key: Makefile.am
# [+] Found file, updating value None for key: Makefile.in
# [+] Found file, updating value None for key: ParseException.h
# [+] Found file, updating value None for key: StringTokenizer.h
# [+] Found file, updating value None for key: WKBConstants.h
# [+] Found file, updating value None for key: WKBReader.h
# [+] Found file, updating value None for key: WKBWriter.h
# [+] Found file, updating value None for key: WKTReader.h
# [+] Found file, updating value None for key: WKTReader.inl
# [+] Found file, updating value None for key: WKTWriter.h
# [+] Found file, updating value None for key: Writer.h
# [+] Found file, updating value None for key: io.h
# [+] Found directory, updating value {} for key: linearref
# [*] Performing recursive function call on: .\matplotlibstuff\basemap-1.1.0\geos-3.3.3\include\geos\linearref
# [+] Found file, updating value None for key: ExtractLineByLocation.h
# ...
# [+] Found file, updating value None for key: test_inlinequeryresultgif.py
# [+] Found file, updating value None for key: test_inlinequeryresultlocation.py
# [+] Found file, updating value None for key: test_inlinequeryresultmpeg4gif.py
# [+] Found file, updating value None for key: test_inlinequeryresultphoto.py
# [+] Found file, updating value None for key: test_inlinequeryresultvenue.py
# [+] Found file, updating value None for key: test_inlinequeryresultvideo.py
# [+] Found file, updating value None for key: test_inlinequeryresultvoice.py
# [+] Found file, updating value None for key: test_inputcontactmessagecontent.py
# [+] Found file, updating value None for key: test_inputfile.py
# [+] Found file, updating value None for key: test_inputlocationmessagecontent.py
# [+] Found file, updating value None for key: test_inputmedia.py
# [+] Found file, updating value None for key: test_inputtextmessagecontent.py
# [+] Found file, updating value None for key: test_inputvenuemessagecontent.py
# [+] Found file, updating value None for key: test_invoice.py
# [+] Found file, updating value None for key: test_jobqueue.py
# [+] Found file, updating value None for key: test_keyboardbutton.py
# [+] Found file, updating value None for key: test_labeledprice.py
# [+] Found file, updating value None for key: test_location.py
# [+] Found file, updating value None for key: test_message.py
# [+] Found file, updating value None for key: test_messageentity.py
# [+] Found file, updating value None for key: test_messagehandler.py
# [+] Found file, updating value None for key: test_messagequeue.py
# [+] Found file, updating value None for key: test_meta.py
# [+] Found file, updating value None for key: test_official.py
# [+] Found file, updating value None for key: test_orderinfo.py
# [+] Found file, updating value None for key: test_parsemode.py
# [+] Found file, updating value None for key: test_passport.py
# [+] Found file, updating value None for key: test_passportelementerrordatafield.py
# [+] Found file, updating value None for key: test_passportelementerrorfile.py
# [+] Found file, updating value None for key: test_passportelementerrorfiles.py
# [+] Found file, updating value None for key: test_passportelementerrorfrontside.py
# [+] Found file, updating value None for key: test_passportelementerrorreverseside.py
# [+] Found file, updating value None for key: test_passportelementerrorselfie.py
# [+] Found file, updating value None for key: test_passportelementerrortranslationfile.py
# [+] Found file, updating value None for key: test_passportelementerrortranslationfiles.py
# [+] Found file, updating value None for key: test_passportelementerrorunspecified.py
# [+] Found file, updating value None for key: test_passportfile.py
# [+] Found file, updating value None for key: test_persistence.py
# [+] Found file, updating value None for key: test_photo.py
# [+] Found file, updating value None for key: test_precheckoutquery.py
# [+] Found file, updating value None for key: test_precheckoutqueryhandler.py
# [+] Found file, updating value None for key: test_regexhandler.py
# [+] Found file, updating value None for key: test_replykeyboardmarkup.py
# [+] Found file, updating value None for key: test_replykeyboardremove.py
# [+] Found file, updating value None for key: test_request.py
# [+] Found file, updating value None for key: test_shippingaddress.py
# [+] Found file, updating value None for key: test_shippingoption.py
# [+] Found file, updating value None for key: test_shippingquery.py
# [+] Found file, updating value None for key: test_shippingqueryhandler.py
# [+] Found file, updating value None for key: test_sticker.py
# [+] Found file, updating value None for key: test_stringcommandhandler.py
# [+] Found file, updating value None for key: test_stringregexhandler.py
# [+] Found file, updating value None for key: test_successfulpayment.py
# [+] Found file, updating value None for key: test_telegramobject.py
# [+] Found file, updating value None for key: test_typehandler.py
# [+] Found file, updating value None for key: test_update.py
# [+] Found file, updating value None for key: test_updater.py
# [+] Found file, updating value None for key: test_user.py
# [+] Found file, updating value None for key: test_userprofilephotos.py
# [+] Found file, updating value None for key: test_venue.py
# [+] Found file, updating value None for key: test_video.py
# [+] Found file, updating value None for key: test_videonote.py
# [+] Found file, updating value None for key: test_voice.py
# [+] Found file, updating value None for key: travis_fold.py
# [+] Found file, updating value None for key: __init__.py
# [+] Found file, updating value None for key: PythonClasses.ipynb
# [+] Found file, updating value None for key: regex.ipynb
# [+] Found file, updating value None for key: RegexPhoneNumbers.ipynb
# [+] Found file, updating value None for key: Selenium.ipynb
# [+] Found file, updating value None for key: selenium.xlsx
# [+] Found directory, updating value {} for key: sorted
# [*] Performing recursive function call on: .\sorted
# [+] Found file, updating value None for key: acdlqmfqoysx.txt
# [+] Found file, updating value None for key: amwejlksqsmx.txt
# [+] Found file, updating value None for key: bfdwkdkegzhb.txt
# [+] Found file, updating value None for key: biupuozacbga.txt
# [+] Found file, updating value None for key: bvxvsoptbvyf.txt
# [+] Found file, updating value None for key: cctpdmwsifvj.txt
# [+] Found file, updating value None for key: cgzghamhspnm.txt
# [+] Found file, updating value None for key: cjizonpukser.txt
# [+] Found file, updating value None for key: clqcldybhiur.txt
# [+] Found file, updating value None for key: crhqceofjkps.txt
# [+] Found file, updating value None for key: cybhfpkphavc.txt
# [+] Found file, updating value None for key: dbqoposhxxhw.txt
# [+] Found file, updating value None for key: dcsnlrkiqbxp.txt
# [+] Found file, updating value None for key: ddtmoeuymiqq.txt
# [+] Found file, updating value None for key: ddtrpioxnmcl.txt
# [+] Found file, updating value None for key: dlpmpmxwsfjl.txt
# [+] Found file, updating value None for key: dshnlfewhfig.txt
# [+] Found file, updating value None for key: dsjytzgcctxe.txt
# [+] Found file, updating value None for key: dtqkbcsldljy.txt
# [+] Found file, updating value None for key: duutwjpfbqya.txt
# [+] Found file, updating value None for key: dvgnnucfgjnq.txt
# [+] Found file, updating value None for key: dzhgnhuouvgc.txt
# [+] Found file, updating value None for key: eezrzcbffbad.txt
# [+] Found file, updating value None for key: egcajnubmdpc.txt
# [+] Found file, updating value None for key: emspkoiqfrjs.txt
# [+] Found file, updating value None for key: enbzxgpnknep.txt
# [+] Found file, updating value None for key: exuuimrabhmh.txt
# [+] Found file, updating value None for key: eyyxvlmhzkqz.txt
# [+] Found file, updating value None for key: fbimupnhdzor.txt
# [+] Found file, updating value None for key: fjyingutmfge.txt
# [+] Found file, updating value None for key: fkuknfbasfhz.txt
# [+] Found file, updating value None for key: flqbwnoekaci.txt
# [+] Found file, updating value None for key: fqrjejsveqax.txt
# [+] Found file, updating value None for key: gcgfzykddyia.txt
# [+] Found file, updating value None for key: gcmoausdingy.txt
# [+] Found file, updating value None for key: ghmaxmmmpzop.txt
# [+] Found file, updating value None for key: ghnyuyjpqbxt.txt
# [+] Found file, updating value None for key: glkflimdpmjb.txt
# [+] Found file, updating value None for key: gqiwejsndpun.txt
# [+] Found file, updating value None for key: gspifmhvajjt.txt
# [+] Found file, updating value None for key: gyoshygbzqhg.txt
# [+] Found file, updating value None for key: hgkmkujopcan.txt
# [+] Found file, updating value None for key: hiehssatgwve.txt
# [+] Found file, updating value None for key: hoedsdcgvjxw.txt
# [+] Found file, updating value None for key: htafufpjcbib.txt
# [+] Found file, updating value None for key: hzhgotgstwpm.txt
# [+] Found file, updating value None for key: imbvfyssackg.txt
# [+] Found file, updating value None for key: iqbjarkzniup.txt
# [+] Found file, updating value None for key: iqlvukkifmav.txt
# [+] Found file, updating value None for key: itkxfxpwivzq.txt
# [+] Found file, updating value None for key: ivuwaeqofykj.txt
# [+] Found file, updating value None for key: iwtullxbivtl.txt
# [+] Found file, updating value None for key: iynrcgarokwa.txt
# [+] Found file, updating value None for key: jijgilrxffmp.txt
# [+] Found file, updating value None for key: jjchnkreiozg.txt
# [+] Found file, updating value None for key: jkqrjehlzbid.txt
# [+] Found file, updating value None for key: jrzgqultjncb.txt
# [+] Found file, updating value None for key: jveakworsnzl.txt
# [+] Found file, updating value None for key: jvwqsysdffvs.txt
# [+] Found file, updating value None for key: jxnejzspjpwn.txt
# [+] Found file, updating value None for key: kacaphsrpjmp.txt
# [+] Found file, updating value None for key: kiwwafpzrxtu.txt
# [+] Found file, updating value None for key: kymckdprbdlr.txt
# [+] Found file, updating value None for key: lbkmvkejhtqb.txt
# [+] Found file, updating value None for key: ldcfoevdwpfd.txt
# [+] Found file, updating value None for key: llcsbwsxilsy.txt
# [+] Found file, updating value None for key: lluivboybjqg.txt
# [+] Found file, updating value None for key: lpjmeybfocvj.txt
# [+] Found file, updating value None for key: lqxhmmrxmmbr.txt
# [+] Found file, updating value None for key: mlkrvgrvkbjs.txt
# [+] Found file, updating value None for key: moacznwqijpk.txt
# [+] Found file, updating value None for key: mougererwkee.txt
# [+] Found file, updating value None for key: mourhveydqia.txt
# [+] Found file, updating value None for key: mppljhzzfwer.txt
# [+] Found file, updating value None for key: mqrhpnsyeieu.txt
# [+] Found file, updating value None for key: mqwvzvgrhfdp.txt
# [+] Found file, updating value None for key: mskvikukhucw.txt
# [+] Found file, updating value None for key: murqsvyevmen.txt
# [+] Found file, updating value None for key: mxanfooknqke.txt
# [+] Found file, updating value None for key: nbkgzzvfrmqj.txt
# [+] Found file, updating value None for key: ncefiqncvgfs.txt
# [+] Found file, updating value None for key: ndadcnmjrcdb.txt
# [+] Found file, updating value None for key: nexatqyslyvr.txt
# [+] Found file, updating value None for key: nfziuidrjrbq.txt
# [+] Found file, updating value None for key: ngwwyoiculof.txt
# [+] Found file, updating value None for key: nnrtwccnwwex.txt
# [+] Found file, updating value None for key: nnzfqrxfupvb.txt
# [+] Found file, updating value None for key: nobvnspeuczh.txt
# [+] Found file, updating value None for key: nrbxehxyeoul.txt
# [+] Found file, updating value None for key: nvfdjpmnjnhh.txt
# [+] Found file, updating value None for key: nvinwvjnekca.txt
# [+] Found file, updating value None for key: nzlfbmbbjbgn.txt
# [+] Found file, updating value None for key: ohrgpnbfpmwb.txt
# [+] Found file, updating value None for key: onedtkhfbrxi.txt
# [+] Found file, updating value None for key: oqqlhlrckcqg.txt
# [+] Found file, updating value None for key: osxbesnjeecg.txt
# [+] Found file, updating value None for key: ouhoyiysioiu.txt
# [+] Found file, updating value None for key: owytaxovvnqj.txt
# [+] Found file, updating value None for key: ozclhofadaoc.txt
# [+] Found file, updating value None for key: pgwtzgvwuuok.txt
# [+] Found file, updating value None for key: poojoxkjizfy.txt
# [+] Found file, updating value None for key: pqqwmeldolmp.txt
# [+] Found file, updating value None for key: ptpwwqxzcilz.txt
# [+] Found file, updating value None for key: pwjgzfmulcnd.txt
# [+] Found file, updating value None for key: pyiovwvbheyh.txt
# [+] Found file, updating value None for key: pzuglulvedhn.txt
# [+] Found file, updating value None for key: qdcvztbvnhhd.txt
# [+] Found file, updating value None for key: qhzwekvtuwzn.txt
# [+] Found file, updating value None for key: qjtxaohcgsik.txt
# [+] Found file, updating value None for key: qksvsfcvngst.txt
# [+] Found file, updating value None for key: qngvyajiwmto.txt
# [+] Found file, updating value None for key: qtltchlrindy.txt
# [+] Found file, updating value None for key: quigoryoplpp.txt
# [+] Found file, updating value None for key: rclsprppbwsh.txt
# [+] Found file, updating value None for key: rdlkgffprizn.txt
# [+] Found file, updating value None for key: rkjworvesapy.txt
# [+] Found file, updating value None for key: rnytssleyqhs.txt
# [+] Found file, updating value None for key: rxupkeuibdem.txt
# [+] Found file, updating value None for key: ryvxjobqjlqw.txt
# [+] Found file, updating value None for key: rzdomgnpmdgi.txt
# [+] Found file, updating value None for key: saqqnedwddip.txt
# [+] Found file, updating value None for key: solsvlzhanyv.txt
# [+] Found file, updating value None for key: spfuftrxcahg.txt
# [+] Found file, updating value None for key: sthwffgdbite.txt
# [+] Found file, updating value None for key: suzfnuhpiggr.txt
# [+] Found file, updating value None for key: sxzudcfrsste.txt
# [+] Found file, updating value None for key: tpxggbsezafk.txt
# [+] Found file, updating value None for key: tqujbblggdak.txt
# [+] Found file, updating value None for key: tshysawbhtdl.txt
# [+] Found file, updating value None for key: uaaqfppmqxsa.txt
# [+] Found file, updating value None for key: ugdieeikupob.txt
# [+] Found file, updating value None for key: ugdmjxknxwin.txt
# [+] Found file, updating value None for key: uiklmeqfiuum.txt
# [+] Found file, updating value None for key: ujkobgrbtuwb.txt
# [+] Found file, updating value None for key: ulfdlfcucckw.txt
# [+] Found file, updating value None for key: unuhqeabfcwm.txt
# [+] Found file, updating value None for key: usblpqrcbior.txt
# [+] Found file, updating value None for key: utscnkmapxmy.txt
# [+] Found file, updating value None for key: uuqwhyjishfz.txt
# [+] Found file, updating value None for key: uvsjhfzetofj.txt
# [+] Found file, updating value None for key: uvzqgxrzddym.txt
# [+] Found file, updating value None for key: vgmspktmdshm.txt
# [+] Found file, updating value None for key: vihrvpzzisno.txt
# [+] Found file, updating value None for key: vndesfvegxeh.txt
# [+] Found file, updating value None for key: vsnksvvytgdm.txt
# [+] Found file, updating value None for key: vwrxhcndxtxm.txt
# [+] Found file, updating value None for key: vycyueukidzw.txt
# [+] Found file, updating value None for key: wnaaolwflwyz.txt
# [+] Found file, updating value None for key: wvnocezmejig.txt
# [+] Found file, updating value None for key: wwarnejfpeow.txt
# [+] Found file, updating value None for key: wzwzmpsyzpwk.txt
# [+] Found file, updating value None for key: xgixwbzvspfr.txt
# [+] Found file, updating value None for key: xlfgkgrybebh.txt
# [+] Found file, updating value None for key: xowkdxqvuqrh.txt
# [+] Found file, updating value None for key: xrrkkbcggpwa.txt
# [+] Found file, updating value None for key: xsweediukjaz.txt
# [+] Found file, updating value None for key: xzqpwzocxzfz.txt
# [+] Found file, updating value None for key: yfqlgpbpgfqg.txt
# [+] Found file, updating value None for key: yjgjaigunuel.txt
# [+] Found file, updating value None for key: yjlnztrtnfrv.txt
# [+] Found file, updating value None for key: ynrsbwrawyfy.txt
# [+] Found file, updating value None for key: yxyvycnrkktl.txt
# [+] Found file, updating value None for key: zpbhwudlygwm.txt
# [+] Found file, updating value None for key: zwudlvyntvrz.txt
# [+] Found file, updating value None for key: sort_files.ipynb
# [+] Found file, updating value None for key: steven_camel.jpg
# [+] Found file, updating value None for key: Steven_Fishing.jpg
# [+] Found file, updating value None for key: test.html
# [+] Found file, updating value None for key: todos.json
# [+] Found file, updating value None for key: todos.txt
# [+] Found file, updating value None for key: topnews.csv
# [+] Found file, updating value None for key: topnewsfeed.xml
# [+] Found directory, updating value {} for key: unsorted
# [*] Performing recursive function call on: .\unsorted
# [+] Found file, updating value None for key: Untitled.ipynb
# [+] Found file, updating value None for key: Untitled1.ipynb
# [+] Found file, updating value None for key: Untitled2.ipynb
# [+] Found file, updating value None for key: webcrawl_exercise.ipynb

# %% [markdown]
# #### Exercise 1
#
# Earlier we imported the 'pprint' module. Let's use that now and investigate the output.
#
# The indentation helps the human eye quite a bit here. Note that this is very complicated dictionary. There would be nothing stopping you from enumerating a key directly as well using bracketed dictionary notation.

# %%
pprint.pprint(structure)
# Out:
# {'Learning_Python3.ipynb': None,
#  'Pandas_Tutorial': {'Files': {'BL-Flickr-Images-Book.csv': None,
#                                'olympics.csv': None,
#                                'university_towns.txt': None},
#                      'Pandas_Tutorial.ipynb': None},
#  'PythonClasses.ipynb': None,
#  'basic_database_tech.ipynb': None,
#  'basic_web_beautifulsoup4.ipynb': None,
#  'basic_web_plus_api_call_interactions.ipynb': None,
#  'dedup_files.ipynb': None,
#  'duplicated': {'bptgxdeeipxu.txt': None,
#                 'fjiwtpgtgcdb.txt': None,
#                 'ibdlnqtlvaim.txt': None,
#                 'icspsjlksrbn.txt': None,
#                 'ioipomykrfom.txt': None,
#                 'jjiihzujdnki.txt': None,
#                 'jnvkounpkeit.txt': None,
#                 'lixeoutjwbtq.txt': None,
#                 'ljmndgqywrsi.txt': None,
#                 'lksequmqneep.txt': None,
#                 'nexygkahtozc.txt': None,
#                 'nhjxkxizisju.txt': None,
#                 'nlptvthvukcc.txt': None,
#                 'ocdwilpcpyme.txt': None,
#                 'odzmgnfcelwt.txt': None,
#                 'ogtwqijwefst.txt': None,
#                 'ovcsvnhebmxw.txt': None,
#                 'pdqzkppwvtbg.txt': None,
#                 'pedjujehkslo.txt': None,
#                 'qcdjkdlivhdl.txt': None,
#                 'qqrtcsambixf.txt': None,
#                 'rgnxruhulrqj.txt': None,
#                 'rsxuxfpjcpjg.txt': None,
#                 'rvavktnfzdhr.txt': None,
#                 'sfhxhyvdufzy.txt': None,
#                 'snqnqfljwwyi.txt': None,
#                 'tfceklaffttv.txt': None,
#                 'tnyyedaupagf.txt': None,
#                 'wexmbvsmavlo.txt': None,
#                 'xksdojojgywa.txt': None,
#                 'xpqwrdqcodwb.txt': None,
#                 'xqagxkswzyuu.txt': None,
#                 'xwbozdzaqmbm.txt': None,
#                 'ydutrxodquup.txt': None,
#                 'yvmexqkrvceb.txt': None,
#                 'zblwvaddjjpv.txt': None},
#  'exceptions_functions_and_dictionaries.ipynb': None,
#  'sort_files.ipynb': None,
#  'sorted': {'acdlqmfqoysx.txt': None,
#             'amwejlksqsmx.txt': None,
#             'bfdwkdkegzhb.txt': None,
#             'biupuozacbga.txt': None,
#             'bvxvsoptbvyf.txt': None,
#             'cctpdmwsifvj.txt': None,
#             'cgzghamhspnm.txt': None,
#             'cjizonpukser.txt': None,
#             'clqcldybhiur.txt': None,
#             'crhqceofjkps.txt': None,
#             'cybhfpkphavc.txt': None,
#             'dbqoposhxxhw.txt': None,
#             'dcsnlrkiqbxp.txt': None,
#             'ddtmoeuymiqq.txt': None,
#             'ddtrpioxnmcl.txt': None,
#             'dlpmpmxwsfjl.txt': None,
#             'dshnlfewhfig.txt': None,
#             'dsjytzgcctxe.txt': None,
#             'dtqkbcsldljy.txt': None,
#             'duutwjpfbqya.txt': None,
#             'dvgnnucfgjnq.txt': None,
#             'dzhgnhuouvgc.txt': None,
#             'eezrzcbffbad.txt': None,
#             'egcajnubmdpc.txt': None,
#             'emspkoiqfrjs.txt': None,
#             'enbzxgpnknep.txt': None,
#             'exuuimrabhmh.txt': None,
#             'eyyxvlmhzkqz.txt': None,
#             'fbimupnhdzor.txt': None,
#             'fjyingutmfge.txt': None,
#             'fkuknfbasfhz.txt': None,
#             'flqbwnoekaci.txt': None,
#             'fqrjejsveqax.txt': None,
#             'gcgfzykddyia.txt': None,
#             'gcmoausdingy.txt': None,
#             'ghmaxmmmpzop.txt': None,
#             'ghnyuyjpqbxt.txt': None,
#             'glkflimdpmjb.txt': None,
#             'gqiwejsndpun.txt': None,
#             'gspifmhvajjt.txt': None,
#             'gyoshygbzqhg.txt': None,
#             'hgkmkujopcan.txt': None,
#             'hiehssatgwve.txt': None,
#             'hoedsdcgvjxw.txt': None,
#             'htafufpjcbib.txt': None,
#             'hzhgotgstwpm.txt': None,
#             'imbvfyssackg.txt': None,
#             'iqbjarkzniup.txt': None,
#             'iqlvukkifmav.txt': None,
#             'itkxfxpwivzq.txt': None,
#             'ivuwaeqofykj.txt': None,
#             'iwtullxbivtl.txt': None,
#             'iynrcgarokwa.txt': None,
#             'jijgilrxffmp.txt': None,
#             'jjchnkreiozg.txt': None,
#             'jkqrjehlzbid.txt': None,
#             'jrzgqultjncb.txt': None,
#             'jveakworsnzl.txt': None,
#             'jvwqsysdffvs.txt': None,
#             'jxnejzspjpwn.txt': None,
#             'kacaphsrpjmp.txt': None,
#             'kiwwafpzrxtu.txt': None,
#             'kymckdprbdlr.txt': None,
#             'lbkmvkejhtqb.txt': None,
#             'ldcfoevdwpfd.txt': None,
#             'llcsbwsxilsy.txt': None,
#             'lluivboybjqg.txt': None,
#             'lpjmeybfocvj.txt': None,
#             'lqxhmmrxmmbr.txt': None,
#             'mlkrvgrvkbjs.txt': None,
#             'moacznwqijpk.txt': None,
#             'mougererwkee.txt': None,
#             'mourhveydqia.txt': None,
#             'mppljhzzfwer.txt': None,
#             'mqrhpnsyeieu.txt': None,
#             'mqwvzvgrhfdp.txt': None,
#             'mskvikukhucw.txt': None,
#             'murqsvyevmen.txt': None,
#             'mxanfooknqke.txt': None,
#             'nbkgzzvfrmqj.txt': None,
#             'ncefiqncvgfs.txt': None,
#             'ndadcnmjrcdb.txt': None,
#             'nexatqyslyvr.txt': None,
#             'nfziuidrjrbq.txt': None,
#             'ngwwyoiculof.txt': None,
#             'nnrtwccnwwex.txt': None,
#             'nnzfqrxfupvb.txt': None,
#             'nobvnspeuczh.txt': None,
#             'nrbxehxyeoul.txt': None,
#             'nvfdjpmnjnhh.txt': None,
#             'nvinwvjnekca.txt': None,
#             'nzlfbmbbjbgn.txt': None,
#             'ohrgpnbfpmwb.txt': None,
#             'onedtkhfbrxi.txt': None,
#             'oqqlhlrckcqg.txt': None,
#             'osxbesnjeecg.txt': None,
#             'ouhoyiysioiu.txt': None,
#             'owytaxovvnqj.txt': None,
#             'ozclhofadaoc.txt': None,
#             'pgwtzgvwuuok.txt': None,
#             'poojoxkjizfy.txt': None,
#             'pqqwmeldolmp.txt': None,
#             'ptpwwqxzcilz.txt': None,
#             'pwjgzfmulcnd.txt': None,
#             'pyiovwvbheyh.txt': None,
#             'pzuglulvedhn.txt': None,
#             'qdcvztbvnhhd.txt': None,
#             'qhzwekvtuwzn.txt': None,
#             'qjtxaohcgsik.txt': None,
#             'qksvsfcvngst.txt': None,
#             'qngvyajiwmto.txt': None,
#             'qtltchlrindy.txt': None,
#             'quigoryoplpp.txt': None,
#             'rclsprppbwsh.txt': None,
#             'rdlkgffprizn.txt': None,
#             'rkjworvesapy.txt': None,
#             'rnytssleyqhs.txt': None,
#             'rxupkeuibdem.txt': None,
#             'ryvxjobqjlqw.txt': None,
#             'rzdomgnpmdgi.txt': None,
#             'saqqnedwddip.txt': None,
#             'solsvlzhanyv.txt': None,
#             'spfuftrxcahg.txt': None,
#             'sthwffgdbite.txt': None,
#             'suzfnuhpiggr.txt': None,
#             'sxzudcfrsste.txt': None,
#             'tpxggbsezafk.txt': None,
#             'tqujbblggdak.txt': None,
#             'tshysawbhtdl.txt': None,
#             'uaaqfppmqxsa.txt': None,
#             'ugdieeikupob.txt': None,
#             'ugdmjxknxwin.txt': None,
#             'uiklmeqfiuum.txt': None,
#             'ujkobgrbtuwb.txt': None,
#             'ulfdlfcucckw.txt': None,
#             'unuhqeabfcwm.txt': None,
#             'usblpqrcbior.txt': None,
#             'utscnkmapxmy.txt': None,
#             'uuqwhyjishfz.txt': None,
#             'uvsjhfzetofj.txt': None,
#             'uvzqgxrzddym.txt': None,
#             'vgmspktmdshm.txt': None,
#             'vihrvpzzisno.txt': None,
#             'vndesfvegxeh.txt': None,
#             'vsnksvvytgdm.txt': None,
#             'vwrxhcndxtxm.txt': None,
#             'vycyueukidzw.txt': None,
#             'wnaaolwflwyz.txt': None,
#             'wvnocezmejig.txt': None,
#             'wwarnejfpeow.txt': None,
#             'wzwzmpsyzpwk.txt': None,
#             'xgixwbzvspfr.txt': None,
#             'xlfgkgrybebh.txt': None,
#             'xowkdxqvuqrh.txt': None,
#             'xrrkkbcggpwa.txt': None,
#             'xsweediukjaz.txt': None,
#             'xzqpwzocxzfz.txt': None,
#             'yfqlgpbpgfqg.txt': None,
#             'yjgjaigunuel.txt': None,
#             'yjlnztrtnfrv.txt': None,
#             'ynrsbwrawyfy.txt': None,
#             'yxyvycnrkktl.txt': None,
#             'zpbhwudlygwm.txt': None,
#             'zwudlvyntvrz.txt': None},
#  'test.html': None,
#  'unsorted': {}}

# %%
# NOTE: This may vary depending on Python version installed and Windows/Linux
# Ensure you can print a valid path below based off looking at the earlier dictionary structure contents
pprint.pprint(structure['venv']['lib']['python3.7'])

# %% [markdown]
# ##### Exercise 2
#
# Convert the following pseudo code to a valid recursive function.
#
# Note we haven't explored the concept of arbitrary keyword arguements passed to a function. Here we have an optional 'depth' keyword argument that is used to appropriately pad the output for the human at the terminal. You'll need to do some research on the syntax of kwargs to see how to pass this appropriately.

# %%
'''
Print a tree directory from the structure dictionary

This is loosely based on the Linux 'tree' command.

https://www.cyberciti.biz/faq/linux-show-directory-structure-command-line/
'''

def recursive_directory_print(structure, **kwargs):
    for item in structure:

        depth       = kwargs.get('depth', 0)
        file_prefix = '|' + '-' * depth
        dir_prefix  = '+' + '-' * depth
        
        # NOT IMPLEMENTED YET - make me print yo
        
        if type(structure[item]) == dict:
            print(dir_prefix, item)
            depth = depth + 1
            recursive_directory_print(structure[item], depth=depth)
                
        
        elif structure[item] == None:
            print(file_prefix, item)

        # if type of structure[item] is dictionary
            # print directory prefix, item
            # add 1 to depth of printint
            # recursive function call passing structure[item] and depth kwarg
            
        # if structure[item] equals None
            # print file prefix, item

recursive_directory_print(structure)
# Out:
# | basic_database_tech.ipynb
# | basic_web_beautifulsoup4.ipynb
# | basic_web_plus_api_call_interactions.ipynb
# | dedup_files.ipynb
# + duplicated
# |- bptgxdeeipxu.txt
# |- fjiwtpgtgcdb.txt
# |- ibdlnqtlvaim.txt
# |- icspsjlksrbn.txt
# |- ioipomykrfom.txt
# |- jjiihzujdnki.txt
# |- jnvkounpkeit.txt
# |- lixeoutjwbtq.txt
# |- ljmndgqywrsi.txt
# |- lksequmqneep.txt
# |- nexygkahtozc.txt
# |- nhjxkxizisju.txt
# |- nlptvthvukcc.txt
# |- ocdwilpcpyme.txt
# |- odzmgnfcelwt.txt
# |- ogtwqijwefst.txt
# |- ovcsvnhebmxw.txt
# |- pdqzkppwvtbg.txt
# |- pedjujehkslo.txt
# |- qcdjkdlivhdl.txt
# |- qqrtcsambixf.txt
# |- rgnxruhulrqj.txt
# |- rsxuxfpjcpjg.txt
# |- rvavktnfzdhr.txt
# |- sfhxhyvdufzy.txt
# |- snqnqfljwwyi.txt
# |- tfceklaffttv.txt
# |- tnyyedaupagf.txt
# |- wexmbvsmavlo.txt
# |- xksdojojgywa.txt
# |- xpqwrdqcodwb.txt
# |- xqagxkswzyuu.txt
# |- xwbozdzaqmbm.txt
# |- ydutrxodquup.txt
# |- yvmexqkrvceb.txt
# |- zblwvaddjjpv.txt
# | exceptions_functions_and_dictionaries.ipynb
# | Learning_Python3.ipynb
# + Pandas_Tutorial
# +- Files
# |-- BL-Flickr-Images-Book.csv
# |-- olympics.csv
# |-- university_towns.txt
# |- Pandas_Tutorial.ipynb
# | PythonClasses.ipynb
# + sorted
# |- acdlqmfqoysx.txt
# |- amwejlksqsmx.txt
# |- bfdwkdkegzhb.txt
# |- biupuozacbga.txt
# |- bvxvsoptbvyf.txt
# |- cctpdmwsifvj.txt
# |- cgzghamhspnm.txt
# |- cjizonpukser.txt
# |- clqcldybhiur.txt
# |- crhqceofjkps.txt
# |- cybhfpkphavc.txt
# |- dbqoposhxxhw.txt
# |- dcsnlrkiqbxp.txt
# |- ddtmoeuymiqq.txt
# |- ddtrpioxnmcl.txt
# |- dlpmpmxwsfjl.txt
# |- dshnlfewhfig.txt
# |- dsjytzgcctxe.txt
# |- dtqkbcsldljy.txt
# |- duutwjpfbqya.txt
# |- dvgnnucfgjnq.txt
# |- dzhgnhuouvgc.txt
# |- eezrzcbffbad.txt
# |- egcajnubmdpc.txt
# |- emspkoiqfrjs.txt
# |- enbzxgpnknep.txt
# |- exuuimrabhmh.txt
# |- eyyxvlmhzkqz.txt
# |- fbimupnhdzor.txt
# |- fjyingutmfge.txt
# |- fkuknfbasfhz.txt
# |- flqbwnoekaci.txt
# |- fqrjejsveqax.txt
# |- gcgfzykddyia.txt
# |- gcmoausdingy.txt
# |- ghmaxmmmpzop.txt
# |- ghnyuyjpqbxt.txt
# |- glkflimdpmjb.txt
# |- gqiwejsndpun.txt
# |- gspifmhvajjt.txt
# |- gyoshygbzqhg.txt
# |- hgkmkujopcan.txt
# |- hiehssatgwve.txt
# |- hoedsdcgvjxw.txt
# |- htafufpjcbib.txt
# |- hzhgotgstwpm.txt
# |- imbvfyssackg.txt
# |- iqbjarkzniup.txt
# |- iqlvukkifmav.txt
# |- itkxfxpwivzq.txt
# |- ivuwaeqofykj.txt
# |- iwtullxbivtl.txt
# |- iynrcgarokwa.txt
# |- jijgilrxffmp.txt
# |- jjchnkreiozg.txt
# |- jkqrjehlzbid.txt
# |- jrzgqultjncb.txt
# |- jveakworsnzl.txt
# |- jvwqsysdffvs.txt
# |- jxnejzspjpwn.txt
# |- kacaphsrpjmp.txt
# |- kiwwafpzrxtu.txt
# |- kymckdprbdlr.txt
# |- lbkmvkejhtqb.txt
# |- ldcfoevdwpfd.txt
# |- llcsbwsxilsy.txt
# |- lluivboybjqg.txt
# |- lpjmeybfocvj.txt
# |- lqxhmmrxmmbr.txt
# |- mlkrvgrvkbjs.txt
# |- moacznwqijpk.txt
# |- mougererwkee.txt
# |- mourhveydqia.txt
# |- mppljhzzfwer.txt
# |- mqrhpnsyeieu.txt
# |- mqwvzvgrhfdp.txt
# |- mskvikukhucw.txt
# |- murqsvyevmen.txt
# |- mxanfooknqke.txt
# |- nbkgzzvfrmqj.txt
# |- ncefiqncvgfs.txt
# |- ndadcnmjrcdb.txt
# |- nexatqyslyvr.txt
# |- nfziuidrjrbq.txt
# |- ngwwyoiculof.txt
# |- nnrtwccnwwex.txt
# |- nnzfqrxfupvb.txt
# |- nobvnspeuczh.txt
# |- nrbxehxyeoul.txt
# |- nvfdjpmnjnhh.txt
# |- nvinwvjnekca.txt
# |- nzlfbmbbjbgn.txt
# |- ohrgpnbfpmwb.txt
# |- onedtkhfbrxi.txt
# |- oqqlhlrckcqg.txt
# |- osxbesnjeecg.txt
# |- ouhoyiysioiu.txt
# |- owytaxovvnqj.txt
# |- ozclhofadaoc.txt
# |- pgwtzgvwuuok.txt
# |- poojoxkjizfy.txt
# |- pqqwmeldolmp.txt
# |- ptpwwqxzcilz.txt
# |- pwjgzfmulcnd.txt
# |- pyiovwvbheyh.txt
# |- pzuglulvedhn.txt
# |- qdcvztbvnhhd.txt
# |- qhzwekvtuwzn.txt
# |- qjtxaohcgsik.txt
# |- qksvsfcvngst.txt
# |- qngvyajiwmto.txt
# |- qtltchlrindy.txt
# |- quigoryoplpp.txt
# |- rclsprppbwsh.txt
# |- rdlkgffprizn.txt
# |- rkjworvesapy.txt
# |- rnytssleyqhs.txt
# |- rxupkeuibdem.txt
# |- ryvxjobqjlqw.txt
# |- rzdomgnpmdgi.txt
# |- saqqnedwddip.txt
# |- solsvlzhanyv.txt
# |- spfuftrxcahg.txt
# |- sthwffgdbite.txt
# |- suzfnuhpiggr.txt
# |- sxzudcfrsste.txt
# |- tpxggbsezafk.txt
# |- tqujbblggdak.txt
# |- tshysawbhtdl.txt
# |- uaaqfppmqxsa.txt
# |- ugdieeikupob.txt
# |- ugdmjxknxwin.txt
# |- uiklmeqfiuum.txt
# |- ujkobgrbtuwb.txt
# |- ulfdlfcucckw.txt
# |- unuhqeabfcwm.txt
# |- usblpqrcbior.txt
# |- utscnkmapxmy.txt
# |- uuqwhyjishfz.txt
# |- uvsjhfzetofj.txt
# |- uvzqgxrzddym.txt
# |- vgmspktmdshm.txt
# |- vihrvpzzisno.txt
# |- vndesfvegxeh.txt
# |- vsnksvvytgdm.txt
# |- vwrxhcndxtxm.txt
# |- vycyueukidzw.txt
# |- wnaaolwflwyz.txt
# |- wvnocezmejig.txt
# |- wwarnejfpeow.txt
# |- wzwzmpsyzpwk.txt
# |- xgixwbzvspfr.txt
# |- xlfgkgrybebh.txt
# |- xowkdxqvuqrh.txt
# |- xrrkkbcggpwa.txt
# |- xsweediukjaz.txt
# |- xzqpwzocxzfz.txt
# |- yfqlgpbpgfqg.txt
# |- yjgjaigunuel.txt
# |- yjlnztrtnfrv.txt
# |- ynrsbwrawyfy.txt
# |- yxyvycnrkktl.txt
# |- zpbhwudlygwm.txt
# |- zwudlvyntvrz.txt
# | sort_files.ipynb
# | test.html
# + unsorted

# %% [markdown]
# #### Exercise 3
#
# Copy/paste the recursive_directory_tree() above into the code block below. Add a new kwarg for a specific file type and add a check for "endswith" that file type.  Search for a 'mp3' or another type of media you have on your system and ensure after running the block of code below that the code above will only print that type of file.

# %%
# NOT IMPLEMENTED YET - exercise 3 goes here

def recursive_directory_print(path, **kwargs, **kwargs2  #ALL OF THIS SHIT IS WRONG AS FUCK
    for item in structure:

        depth       = kwargs.get('depth', 0)
        docx        = kwargs2
        file_prefix = '|' + '-' * depth
        dir_prefix  = '+' + '-' * depth
        
        # NOT IMPLEMENTED YET - make me print yo
        
        if type(structure[item]) == dict:
            print(dir_prefix, item)
            depth = depth + 1
            recursive_directory_print(structure[item], depth=depth)
                
        
        elif structure[item] == None:
            print(file_prefix, item)

# %% [markdown]
# #### Exercise 4
#
# Review alternate techniques for accomplishing the above. Keep in mind that sometimes you won't have to reinvent the wheel.

# %%
# Basic example of printing all files and directories (non tree style)
for root, dirs, files in os.walk(path, topdown=False):
   for name in files: print(os.path.join(root, name))
   for name in dirs:  print(os.path.join(root, name))
# Out:
# .\.ipynb_checkpoints\basic_database_tech-checkpoint.ipynb
# .\.ipynb_checkpoints\basic_web_beautifulsoup4-checkpoint.ipynb
# .\.ipynb_checkpoints\dedup_files-checkpoint.ipynb
# .\.ipynb_checkpoints\exceptions_functions_and_dictionaries-checkpoint.ipynb
# .\duplicated\bptgxdeeipxu.txt
# .\duplicated\fjiwtpgtgcdb.txt
# .\duplicated\ibdlnqtlvaim.txt
# .\duplicated\icspsjlksrbn.txt
# .\duplicated\ioipomykrfom.txt
# .\duplicated\jjiihzujdnki.txt
# .\duplicated\jnvkounpkeit.txt
# .\duplicated\lixeoutjwbtq.txt
# .\duplicated\ljmndgqywrsi.txt
# .\duplicated\lksequmqneep.txt
# .\duplicated\nexygkahtozc.txt
# .\duplicated\nhjxkxizisju.txt
# .\duplicated\nlptvthvukcc.txt
# .\duplicated\ocdwilpcpyme.txt
# .\duplicated\odzmgnfcelwt.txt
# .\duplicated\ogtwqijwefst.txt
# .\duplicated\ovcsvnhebmxw.txt
# .\duplicated\pdqzkppwvtbg.txt
# .\duplicated\pedjujehkslo.txt
# .\duplicated\qcdjkdlivhdl.txt
# .\duplicated\qqrtcsambixf.txt
# .\duplicated\rgnxruhulrqj.txt
# .\duplicated\rsxuxfpjcpjg.txt
# .\duplicated\rvavktnfzdhr.txt
# .\duplicated\sfhxhyvdufzy.txt
# .\duplicated\snqnqfljwwyi.txt
# .\duplicated\tfceklaffttv.txt
# .\duplicated\tnyyedaupagf.txt
# .\duplicated\wexmbvsmavlo.txt
# .\duplicated\xksdojojgywa.txt
# .\duplicated\xpqwrdqcodwb.txt
# .\duplicated\xqagxkswzyuu.txt
# .\duplicated\xwbozdzaqmbm.txt
# .\duplicated\ydutrxodquup.txt
# .\duplicated\yvmexqkrvceb.txt
# .\duplicated\zblwvaddjjpv.txt
# .\Pandas_Tutorial\.ipynb_checkpoints\Pandas_Tutorial-checkpoint.ipynb
# .\Pandas_Tutorial\Files\BL-Flickr-Images-Book.csv
# .\Pandas_Tutorial\Files\olympics.csv
# .\Pandas_Tutorial\Files\university_towns.txt
# .\Pandas_Tutorial\Pandas_Tutorial.ipynb
# .\Pandas_Tutorial\.ipynb_checkpoints
# .\Pandas_Tutorial\Files
# .\sorted\acdlqmfqoysx.txt
# .\sorted\amwejlksqsmx.txt
# .\sorted\bfdwkdkegzhb.txt
# .\sorted\biupuozacbga.txt
# .\sorted\bvxvsoptbvyf.txt
# .\sorted\cctpdmwsifvj.txt
# .\sorted\cgzghamhspnm.txt
# .\sorted\cjizonpukser.txt
# .\sorted\clqcldybhiur.txt
# .\sorted\crhqceofjkps.txt
# .\sorted\cybhfpkphavc.txt
# .\sorted\dbqoposhxxhw.txt
# .\sorted\dcsnlrkiqbxp.txt
# .\sorted\ddtmoeuymiqq.txt
# .\sorted\ddtrpioxnmcl.txt
# .\sorted\dlpmpmxwsfjl.txt
# .\sorted\dshnlfewhfig.txt
# .\sorted\dsjytzgcctxe.txt
# .\sorted\dtqkbcsldljy.txt
# .\sorted\duutwjpfbqya.txt
# .\sorted\dvgnnucfgjnq.txt
# .\sorted\dzhgnhuouvgc.txt
# .\sorted\eezrzcbffbad.txt
# .\sorted\egcajnubmdpc.txt
# .\sorted\emspkoiqfrjs.txt
# .\sorted\enbzxgpnknep.txt
# .\sorted\exuuimrabhmh.txt
# .\sorted\eyyxvlmhzkqz.txt
# .\sorted\fbimupnhdzor.txt
# .\sorted\fjyingutmfge.txt
# .\sorted\fkuknfbasfhz.txt
# .\sorted\flqbwnoekaci.txt
# .\sorted\fqrjejsveqax.txt
# .\sorted\gcgfzykddyia.txt
# .\sorted\gcmoausdingy.txt
# .\sorted\ghmaxmmmpzop.txt
# .\sorted\ghnyuyjpqbxt.txt
# .\sorted\glkflimdpmjb.txt
# .\sorted\gqiwejsndpun.txt
# .\sorted\gspifmhvajjt.txt
# .\sorted\gyoshygbzqhg.txt
# .\sorted\hgkmkujopcan.txt
# .\sorted\hiehssatgwve.txt
# .\sorted\hoedsdcgvjxw.txt
# .\sorted\htafufpjcbib.txt
# .\sorted\hzhgotgstwpm.txt
# .\sorted\imbvfyssackg.txt
# .\sorted\iqbjarkzniup.txt
# .\sorted\iqlvukkifmav.txt
# .\sorted\itkxfxpwivzq.txt
# .\sorted\ivuwaeqofykj.txt
# .\sorted\iwtullxbivtl.txt
# .\sorted\iynrcgarokwa.txt
# .\sorted\jijgilrxffmp.txt
# .\sorted\jjchnkreiozg.txt
# .\sorted\jkqrjehlzbid.txt
# .\sorted\jrzgqultjncb.txt
# .\sorted\jveakworsnzl.txt
# .\sorted\jvwqsysdffvs.txt
# .\sorted\jxnejzspjpwn.txt
# .\sorted\kacaphsrpjmp.txt
# .\sorted\kiwwafpzrxtu.txt
# .\sorted\kymckdprbdlr.txt
# .\sorted\lbkmvkejhtqb.txt
# .\sorted\ldcfoevdwpfd.txt
# .\sorted\llcsbwsxilsy.txt
# .\sorted\lluivboybjqg.txt
# .\sorted\lpjmeybfocvj.txt
# .\sorted\lqxhmmrxmmbr.txt
# .\sorted\mlkrvgrvkbjs.txt
# .\sorted\moacznwqijpk.txt
# .\sorted\mougererwkee.txt
# .\sorted\mourhveydqia.txt
# .\sorted\mppljhzzfwer.txt
# .\sorted\mqrhpnsyeieu.txt
# .\sorted\mqwvzvgrhfdp.txt
# .\sorted\mskvikukhucw.txt
# .\sorted\murqsvyevmen.txt
# .\sorted\mxanfooknqke.txt
# .\sorted\nbkgzzvfrmqj.txt
# .\sorted\ncefiqncvgfs.txt
# .\sorted\ndadcnmjrcdb.txt
# .\sorted\nexatqyslyvr.txt
# .\sorted\nfziuidrjrbq.txt
# .\sorted\ngwwyoiculof.txt
# .\sorted\nnrtwccnwwex.txt
# .\sorted\nnzfqrxfupvb.txt
# .\sorted\nobvnspeuczh.txt
# .\sorted\nrbxehxyeoul.txt
# .\sorted\nvfdjpmnjnhh.txt
# .\sorted\nvinwvjnekca.txt
# .\sorted\nzlfbmbbjbgn.txt
# .\sorted\ohrgpnbfpmwb.txt
# .\sorted\onedtkhfbrxi.txt
# .\sorted\oqqlhlrckcqg.txt
# .\sorted\osxbesnjeecg.txt
# .\sorted\ouhoyiysioiu.txt
# .\sorted\owytaxovvnqj.txt
# .\sorted\ozclhofadaoc.txt
# .\sorted\pgwtzgvwuuok.txt
# .\sorted\poojoxkjizfy.txt
# .\sorted\pqqwmeldolmp.txt
# .\sorted\ptpwwqxzcilz.txt
# .\sorted\pwjgzfmulcnd.txt
# .\sorted\pyiovwvbheyh.txt
# .\sorted\pzuglulvedhn.txt
# .\sorted\qdcvztbvnhhd.txt
# .\sorted\qhzwekvtuwzn.txt
# .\sorted\qjtxaohcgsik.txt
# .\sorted\qksvsfcvngst.txt
# .\sorted\qngvyajiwmto.txt
# .\sorted\qtltchlrindy.txt
# .\sorted\quigoryoplpp.txt
# .\sorted\rclsprppbwsh.txt
# .\sorted\rdlkgffprizn.txt
# .\sorted\rkjworvesapy.txt
# .\sorted\rnytssleyqhs.txt
# .\sorted\rxupkeuibdem.txt
# .\sorted\ryvxjobqjlqw.txt
# .\sorted\rzdomgnpmdgi.txt
# .\sorted\saqqnedwddip.txt
# .\sorted\solsvlzhanyv.txt
# .\sorted\spfuftrxcahg.txt
# .\sorted\sthwffgdbite.txt
# .\sorted\suzfnuhpiggr.txt
# .\sorted\sxzudcfrsste.txt
# .\sorted\tpxggbsezafk.txt
# .\sorted\tqujbblggdak.txt
# .\sorted\tshysawbhtdl.txt
# .\sorted\uaaqfppmqxsa.txt
# .\sorted\ugdieeikupob.txt
# .\sorted\ugdmjxknxwin.txt
# .\sorted\uiklmeqfiuum.txt
# .\sorted\ujkobgrbtuwb.txt
# .\sorted\ulfdlfcucckw.txt
# .\sorted\unuhqeabfcwm.txt
# .\sorted\usblpqrcbior.txt
# .\sorted\utscnkmapxmy.txt
# .\sorted\uuqwhyjishfz.txt
# .\sorted\uvsjhfzetofj.txt
# .\sorted\uvzqgxrzddym.txt
# .\sorted\vgmspktmdshm.txt
# .\sorted\vihrvpzzisno.txt
# .\sorted\vndesfvegxeh.txt
# .\sorted\vsnksvvytgdm.txt
# .\sorted\vwrxhcndxtxm.txt
# .\sorted\vycyueukidzw.txt
# .\sorted\wnaaolwflwyz.txt
# .\sorted\wvnocezmejig.txt
# .\sorted\wwarnejfpeow.txt
# .\sorted\wzwzmpsyzpwk.txt
# .\sorted\xgixwbzvspfr.txt
# .\sorted\xlfgkgrybebh.txt
# .\sorted\xowkdxqvuqrh.txt
# .\sorted\xrrkkbcggpwa.txt
# .\sorted\xsweediukjaz.txt
# .\sorted\xzqpwzocxzfz.txt
# .\sorted\yfqlgpbpgfqg.txt
# .\sorted\yjgjaigunuel.txt
# .\sorted\yjlnztrtnfrv.txt
# .\sorted\ynrsbwrawyfy.txt
# .\sorted\yxyvycnrkktl.txt
# .\sorted\zpbhwudlygwm.txt
# .\sorted\zwudlvyntvrz.txt
# .\basic_database_tech.ipynb
# .\basic_web_beautifulsoup4.ipynb
# .\basic_web_plus_api_call_interactions.ipynb
# .\dedup_files.ipynb
# .\exceptions_functions_and_dictionaries.ipynb
# .\Learning_Python3.ipynb
# .\PythonClasses.ipynb
# .\sort_files.ipynb
# .\test.html
# .\.ipynb_checkpoints
# .\duplicated
# .\Pandas_Tutorial
# .\sorted
# .\unsorted

# %%
path = 'C:\Users\estyw\Desktop'   ####THIS SHIT IS WRONG AS FUCK ALSO
# !pip install py-tree
import py_tree
py_tree.main(path)
# Out:
#   File "<ipython-input-24-5eda1643b23b>", line 1
#     path = 'C:\Users\estyw\Desktop'
#           ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %% [markdown]
# #### Advanced: Exercise 5
#
# Copy/paste the recursive_directory_tree() function and rename it to just directory_tree().  Convert the function to an iterative use where you keep track of the current path you are scanning and iterate through all contents of the file path. You will not call the function within itself in this variant.

# %%
# NOT IMPLENTED YET - exercise 5 goes here
